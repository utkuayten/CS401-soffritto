# %% [markdown]
# <a href="https://colab.research.google.com/github/utkuayten/CS401-soffritto/blob/main/optuna_informer_BOC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install optuna
# !git clone https://github.com/utkuayten/CS401-soffritto
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 8.3 MB/s eta 0:00:00ta 0:00:01
# ...
# Cloning into 'CS401-soffritto'...
# remote: Enumerating objects: 1800, done.
# remote: Counting objects: 100% (276/276), done.
# remote: Compressing objects: 100% (174/174), done.
# remote: Total 1800 (delta 181), reused 183 (delta 102), pack-reused 1524 (from 2)
# Receiving objects: 100% (1800/1800), 764.81 MiB | 25.20 MiB/s, done.
# Resolving deltas: 100% (1004/1004), done.
# Updating files: 100% (555/555), done.

# %%
# %cd CS401-soffritto
# !git pull
# Out:
# /content/CS401-soffritto
# Already up to date.

# %%
# %cd CS401-soffritto/
import torch
print(torch.cuda.is_available())
# Out:
# [Errno 2] No such file or directory: 'CS401-soffritto/'
# /content/CS401-soffritto
# False

# %%
# !python3 transofritto_v2/optuna_BOC.py --cell H1 --n_trials 5 --group_size 10
# Out:
# [I 2025-12-19 12:10:52,949] A new study created in memory with name: no-name-087bf726-768f-4630-b881-86d6694cdf9f
# ...

# %%
# !ls
# Out:
# dataset_feature_selection.ipynb  README.md
# GenomicBert			 run_model.ipynb
# iTransformer			 soffritto
# optuna_BOCO_H1.csv		 train_w_parameters.ipynb
# optuna_informer_BOC.ipynb	 transofritto
# optuna_informer_BOCO.ipynb	 transofritto_v2
# PatchTST			 wavelet_informer.ipynb

# %%
# !cat optuna_BOC_H1.csv
# Out:
# cat: optuna_BOC_H1.csv: No such file or directory
