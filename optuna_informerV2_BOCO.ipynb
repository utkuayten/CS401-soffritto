# %% [markdown]
# <a href="https://colab.research.google.com/github/utkuayten/CS401-soffritto/blob/main/optuna_informer_BOCO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install optuna
# !git clone https://github.com/utkuayten/CS401-soffritto
# Out:
# ...
# Cloning into 'CS401-soffritto'...
# remote: Enumerating objects: 1782, done.
# remote: Counting objects: 100% (258/258), done.
# remote: Compressing objects: 100% (163/163), done.
# remote: Total 1782 (delta 169), reused 170 (delta 95), pack-reused 1524 (from 2)
# Receiving objects: 100% (1782/1782), 764.80 MiB | 44.43 MiB/s, done.
# Resolving deltas: 100% (992/992), done.
# Updating files: 100% (523/523), done.

# %%
# %cd CS401-soffritto
# Out:
# /content/CS401-soffritto

# %%
import torch
print(torch.cuda.is_available())
# Out:
# [Errno 2] No such file or directory: 'CS401-soffritto/'
# /content/CS401-soffritto
# True

# %%
# !python3 transofritto/optuna_BOCO.py --cell H1 --n_trials 5 --group_size 25
# Out:
# [I 2025-11-29 16:23:16,860] A new study created in memory with name: no-name-beb282c5-228e-45b4-9943-de2e0234c418
# [W 2025-11-29 16:23:16,861] Trial 0 failed with parameters: {} because of the following error: ValueError('BOC subset has fewer than 2 chromosomes; increase data or adjust group_size.').
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py", line 205, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/content/CS401-soffritto/transofritto/optuna_BOC.py", line 170, in <lambda>
#     lambda trial: optuna_objective_boc(
#                   ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/CS401-soffritto/transofritto/optuna_BOC.py", line 75, in optuna_objective_boc
#     raise ValueError("BOC subset has fewer than 2 chromosomes; increase data or adjust group_size.")
# ValueError: BOC subset has fewer than 2 chromosomes; increase data or adjust group_size.
# ...

# %%
# !ls

# %%
# !cat optuna_BOC_H1.csv
