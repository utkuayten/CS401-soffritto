# %% [markdown]
# <a href="https://colab.research.google.com/github/utkuayten/CS401-soffritto/blob/main/optuna_informer_2rt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/utkuayten/CS401-soffritto
# Out:
# Cloning into 'CS401-soffritto'...
# remote: Enumerating objects: 2111, done.
# remote: Counting objects: 100% (101/101), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 2111 (delta 49), reused 72 (delta 32), pack-reused 2010 (from 2)
# Receiving objects: 100% (2111/2111), 798.10 MiB | 16.09 MiB/s, done.
# Resolving deltas: 100% (1205/1205), done.
# Updating files: 100% (695/695), done.

# %%
# %cd CS401-soffritto/
# Out:
# /content/CS401-soffritto

# %%
# !pip install optuna
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 30.8 MB/s eta 0:00:00
# ...

# %%
# !python3 transofritto/optuna_intra_cell.py --cell H1 --test_chrom 9 --decode_mode cost_aware_2
# Out:
# [I 2026-01-10 19:03:15,038] A new study created in memory with name: optuna_H1_val6_test9_cost_aware_2
# ...

# %%
# !python3 transofritto/train_intra_cell.py \
  --seq_len 128 \
  --d_model 512 \
  --n_heads 2 \
  --enc_in 9 \
  --dec_in 16 \
  --c_out 16 \
  --e_layers 4 \
  --d_layers 2 \
  --d_ff 512 \
  --dropout 0.05408620124209015 \
  --attn full \
  --factor 3 \
  --activation gelu \
  --learning_rate 0.00024408375279725986 \
  --lradj type3 \
  --weight_decay 3.3963819445255696e-05 \
  --cell H1 \
  --test_chrom 9 \
  --val_chrom 6 \
  --train_epochs 15 \
  --batch_size 512 \
  --decoding_mode cost-aware-2
# Out:
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1310, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/__init__.py", line 15, in <module>
#     from ._chunking import gen_batches, gen_even_slices
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from ._param_validation import Interval, validate_params
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from .validation import _is_arraylike_not_scalar
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py", line 21, in <module>
#     from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
# ...

# %%
# !python3 transofritto/evaluate_informer.py
# Out:
# Saved 3-panel heatmap: eval_outputs/chrom_test_true_vs_ours_vs_other_heatmap.png
#
# Saved (ours):
#   summary_json: eval_outputs/chrom_test_ours_summary_metrics.json
#   confusion_csv: eval_outputs/chrom_test_ours_confusion_matrix.csv
#   confusion_png: eval_outputs/chrom_test_ours_confusion_matrix.png
#   per_bin_csv: eval_outputs/chrom_test_ours_per_bin_metrics.csv
#
# Saved (other):
#   summary_json: eval_outputs/chrom_test_other_summary_metrics.json
#   confusion_csv: eval_outputs/chrom_test_other_confusion_matrix.csv
#   confusion_png: eval_outputs/chrom_test_other_confusion_matrix.png
#   per_bin_csv: eval_outputs/chrom_test_other_per_bin_metrics.csv
