# %% [markdown]
# <a href="https://colab.research.google.com/github/utkuayten/CS401-soffritto/blob/main/optuna_informer_BOC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install optuna
# !git clone https://github.com/utkuayten/CS401-soffritto
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna) (6.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# fatal: destination path 'CS401-soffritto' already exists and is not an empty directory.

# %%
# %cd CS401-soffritto
# !git pull
# Out:
# /content/CS401-soffritto
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 4), reused 5 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 20.16 KiB | 368.00 KiB/s, done.
# From https://github.com/utkuayten/CS401-soffritto
#    88dbd1e..fb563a4  main       -> origin/main
# Updating 88dbd1e..fb563a4
# Fast-forward
#  optuna_informer_BOC.ipynb  | 3782 ++++++++++++++++++++++----------------------
#  transofritto/optuna_BOC.py |   15 +-
#  2 files changed, 1909 insertions(+), 1888 deletions(-)

# %%
# %cd CS401-soffritto/
import torch
print(torch.cuda.is_available())
# Out:
# /content/CS401-soffritto
# True

# %%
# !python3 transofritto/optuna_BOC.py --cell H1 --n_trials 5 --group_size 10
# Out:
# [I 2025-11-26 00:50:07,441] A new study created in memory with name: no-name-0c7165c1-2123-496a-9b32-80189008e520
# Namespace(cell='H1', train_chroms=[17, 21], val_chroms=[7], test_chroms=[7], setting='H1_BOCsubset_trial0_val7', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=1, d_model=512, n_heads=2, d_ff=1024, dropout=0.06333956530584388, learning_rate=0.00015221846086499398, weight_decay=0.0008830462059621119, factor=5, seq_len=32, batch_size=256, label_len=16, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 2207
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 3042
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 3042
# Epoch: 1 cost time: 2.1061296463012695
# Validation KL div loss: 0.585135
# Validation KL div loss: 0.582085
# Epoch: 1, Steps: 8 | Train Loss: 0.4992036 Vali Loss: 0.5851353 Test Loss: 0.5820846
# Validation loss decreased (inf --> 0.585135).  Saving model ...
# Updating learning rate to 0.00015221846086499398
# Epoch: 2 cost time: 1.543917179107666
# Validation KL div loss: 0.366676
# Validation KL div loss: 0.377805
# Epoch: 2, Steps: 8 | Train Loss: 0.3499941 Vali Loss: 0.3666762 Test Loss: 0.3778047
# Validation loss decreased (0.585135 --> 0.366676).  Saving model ...
# Updating learning rate to 7.610923043249699e-05
# Epoch: 3 cost time: 1.529954195022583
# Validation KL div loss: 0.273823
# Validation KL div loss: 0.280703
# Epoch: 3, Steps: 8 | Train Loss: 0.2642711 Vali Loss: 0.2738231 Test Loss: 0.2807030
# Validation loss decreased (0.366676 --> 0.273823).  Saving model ...
# Updating learning rate to 3.8054615216248495e-05
# Epoch: 4 cost time: 1.5262808799743652
# Validation KL div loss: 0.231540
# Validation KL div loss: 0.231036
# Epoch: 4, Steps: 8 | Train Loss: 0.2180382 Vali Loss: 0.2315403 Test Loss: 0.2310355
# Validation loss decreased (0.273823 --> 0.231540).  Saving model ...
# Updating learning rate to 1.9027307608124247e-05
# Epoch: 5 cost time: 1.5178325176239014
# Validation KL div loss: 0.215260
# Validation KL div loss: 0.212501
# Epoch: 5, Steps: 8 | Train Loss: 0.1976119 Vali Loss: 0.2152601 Test Loss: 0.2125009
# Validation loss decreased (0.231540 --> 0.215260).  Saving model ...
# Updating learning rate to 9.513653804062124e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 3042
# test shape: (3042, 1, 16) (3042, 1, 16)
# test shape: (3042, 1, 16) (3042, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial0_val7/H1_BOCsubset_trial0_val7_hyperparameters.json
# [INFO] Validation Score: 0.2152601263739846
# [INFO] Training finished with metrics: {'val_score': 0.2152601263739846}
# Namespace(cell='H1', train_chroms=[7, 21], val_chroms=[17], test_chroms=[17], setting='H1_BOCsubset_trial0_val17', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=1, d_model=512, n_heads=2, d_ff=1024, dropout=0.06333956530584388, learning_rate=0.00015221846086499398, weight_decay=0.0008830462059621119, factor=5, seq_len=32, batch_size=256, label_len=16, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 3729
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 1520
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 1520
# Epoch: 1 cost time: 2.544192314147949
# Validation KL div loss: 0.282127
# Validation KL div loss: 0.279846
# Epoch: 1, Steps: 14 | Train Loss: 0.4671671 Vali Loss: 0.2821272 Test Loss: 0.2798460
# Validation loss decreased (inf --> 0.282127).  Saving model ...
# Updating learning rate to 0.00015221846086499398
# Epoch: 2 cost time: 2.528571605682373
# Validation KL div loss: 0.173854
# Validation KL div loss: 0.173796
# Epoch: 2, Steps: 14 | Train Loss: 0.2115398 Vali Loss: 0.1738545 Test Loss: 0.1737959
# Validation loss decreased (0.282127 --> 0.173854).  Saving model ...
# Updating learning rate to 7.610923043249699e-05
# Epoch: 3 cost time: 2.5558338165283203
# Validation KL div loss: 0.154649
# Validation KL div loss: 0.152316
# Epoch: 3, Steps: 14 | Train Loss: 0.1496532 Vali Loss: 0.1546488 Test Loss: 0.1523159
# Validation loss decreased (0.173854 --> 0.154649).  Saving model ...
# Updating learning rate to 3.8054615216248495e-05
# Epoch: 4 cost time: 2.5455715656280518
# Validation KL div loss: 0.142351
# Validation KL div loss: 0.142296
# Epoch: 4, Steps: 14 | Train Loss: 0.1301504 Vali Loss: 0.1423505 Test Loss: 0.1422960
# Validation loss decreased (0.154649 --> 0.142351).  Saving model ...
# Updating learning rate to 1.9027307608124247e-05
# Epoch: 5 cost time: 2.5251364707946777
# Validation KL div loss: 0.140941
# Validation KL div loss: 0.153057
# Epoch: 5, Steps: 14 | Train Loss: 0.1189620 Vali Loss: 0.1409410 Test Loss: 0.1530574
# Validation loss decreased (0.142351 --> 0.140941).  Saving model ...
# Updating learning rate to 9.513653804062124e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 1520
# test shape: (1520, 1, 16) (1520, 1, 16)
# test shape: (1520, 1, 16) (1520, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial0_val17/H1_BOCsubset_trial0_val17_hyperparameters.json
# [INFO] Validation Score: 0.1409410297870636
# [INFO] Training finished with metrics: {'val_score': 0.1409410297870636}
# Namespace(cell='H1', train_chroms=[7, 17], val_chroms=[21], test_chroms=[21], setting='H1_BOCsubset_trial0_val21', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=1, d_model=512, n_heads=2, d_ff=1024, dropout=0.06333956530584388, learning_rate=0.00015221846086499398, weight_decay=0.0008830462059621119, factor=5, seq_len=32, batch_size=256, label_len=16, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 4594
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 655
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 655
# Epoch: 1 cost time: 3.077230453491211
# Validation KL div loss: 0.227720
# Validation KL div loss: 0.231301
# Epoch: 1, Steps: 17 | Train Loss: 0.3933062 Vali Loss: 0.2277201 Test Loss: 0.2313009
# Validation loss decreased (inf --> 0.227720).  Saving model ...
# Updating learning rate to 0.00015221846086499398
# Epoch: 2 cost time: 3.026639938354492
# Validation KL div loss: 0.118296
# Validation KL div loss: 0.121223
# Epoch: 2, Steps: 17 | Train Loss: 0.1753733 Vali Loss: 0.1182962 Test Loss: 0.1212232
# Validation loss decreased (0.227720 --> 0.118296).  Saving model ...
# Updating learning rate to 7.610923043249699e-05
# Epoch: 3 cost time: 3.0445005893707275
# Validation KL div loss: 0.100515
# Validation KL div loss: 0.101562
# Epoch: 3, Steps: 17 | Train Loss: 0.1242930 Vali Loss: 0.1005147 Test Loss: 0.1015621
# Validation loss decreased (0.118296 --> 0.100515).  Saving model ...
# Updating learning rate to 3.8054615216248495e-05
# Epoch: 4 cost time: 3.063246726989746
# Validation KL div loss: 0.102815
# Validation KL div loss: 0.105698
# Epoch: 4, Steps: 17 | Train Loss: 0.1064319 Vali Loss: 0.1028155 Test Loss: 0.1056975
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.9027307608124247e-05
# Epoch: 5 cost time: 3.033936023712158
# Validation KL div loss: 0.096580
# Validation KL div loss: 0.096903
# Epoch: 5, Steps: 17 | Train Loss: 0.0996530 Vali Loss: 0.0965800 Test Loss: 0.0969027
# Validation loss decreased (0.100515 --> 0.096580).  Saving model ...
# Updating learning rate to 9.513653804062124e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 655
# test shape: (655, 1, 16) (655, 1, 16)
# test shape: (655, 1, 16) (655, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial0_val21/H1_BOCsubset_trial0_val21_hyperparameters.json
# [INFO] Validation Score: 0.09657996147871017
# [INFO] Training finished with metrics: {'val_score': 0.09657996147871017}
# [I 2025-11-26 00:51:09,388] Trial 0 finished with value: 0.1509270392132528 and parameters: {'e_layers': 3, 'd_layers': 1, 'd_model': 512, 'n_heads': 2, 'd_ff': 1024, 'dropout': 0.06333956530584388, 'learning_rate': 0.00015221846086499398, 'weight_decay': 0.0008830462059621119, 'factor': 5, 'seq_len': 32}. Best is trial 0 with value: 0.1509270392132528.
# Namespace(cell='H1', train_chroms=[20, 21], val_chroms=[3], test_chroms=[3], setting='H1_BOCsubset_trial1_val3', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=2, d_layers=3, d_model=256, n_heads=4, d_ff=512, dropout=0.2960404353430677, learning_rate=1.3493665047050212e-05, weight_decay=0.0005258226479500629, factor=5, seq_len=64, batch_size=256, label_len=32, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 1842
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 3730
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 3730
# Epoch: 1 cost time: 1.7084777355194092
# Validation KL div loss: 0.660482
# Validation KL div loss: 0.668585
# Epoch: 1, Steps: 7 | Train Loss: 0.7877905 Vali Loss: 0.6604819 Test Loss: 0.6685850
# Validation loss decreased (inf --> 0.660482).  Saving model ...
# Updating learning rate to 1.3493665047050212e-05
# Epoch: 2 cost time: 1.7082831859588623
# Validation KL div loss: 0.601601
# Validation KL div loss: 0.619931
# Epoch: 2, Steps: 7 | Train Loss: 0.6980475 Vali Loss: 0.6016006 Test Loss: 0.6199308
# Validation loss decreased (0.660482 --> 0.601601).  Saving model ...
# Updating learning rate to 6.746832523525106e-06
# Epoch: 3 cost time: 1.674983024597168
# Validation KL div loss: 0.593264
# Validation KL div loss: 0.600822
# Epoch: 3, Steps: 7 | Train Loss: 0.6578939 Vali Loss: 0.5932643 Test Loss: 0.6008225
# Validation loss decreased (0.601601 --> 0.593264).  Saving model ...
# Updating learning rate to 3.373416261762553e-06
# Epoch: 4 cost time: 1.6867921352386475
# Validation KL div loss: 0.585074
# Validation KL div loss: 0.594832
# Epoch: 4, Steps: 7 | Train Loss: 0.6522282 Vali Loss: 0.5850737 Test Loss: 0.5948324
# Validation loss decreased (0.593264 --> 0.585074).  Saving model ...
# Updating learning rate to 1.6867081308812765e-06
# Epoch: 5 cost time: 1.688849925994873
# Validation KL div loss: 0.579803
# Validation KL div loss: 0.559848
# Epoch: 5, Steps: 7 | Train Loss: 0.6422124 Vali Loss: 0.5798030 Test Loss: 0.5598482
# Validation loss decreased (0.585074 --> 0.579803).  Saving model ...
# Updating learning rate to 8.433540654406383e-07
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 3730
# test shape: (3730, 1, 16) (3730, 1, 16)
# test shape: (3730, 1, 16) (3730, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial1_val3/H1_BOCsubset_trial1_val3_hyperparameters.json
# [INFO] Validation Score: 0.579802964414869
# [INFO] Training finished with metrics: {'val_score': 0.579802964414869}
# Namespace(cell='H1', train_chroms=[3, 21], val_chroms=[20], test_chroms=[20], setting='H1_BOCsubset_trial1_val20', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=2, d_layers=3, d_model=256, n_heads=4, d_ff=512, dropout=0.2960404353430677, learning_rate=1.3493665047050212e-05, weight_decay=0.0005258226479500629, factor=5, seq_len=64, batch_size=256, label_len=32, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 4417
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 1155
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 1155
# Epoch: 1 cost time: 3.869985580444336
# Validation KL div loss: 0.590370
# Validation KL div loss: 0.575768
# Epoch: 1, Steps: 17 | Train Loss: 0.6545014 Vali Loss: 0.5903702 Test Loss: 0.5757675
# Validation loss decreased (inf --> 0.590370).  Saving model ...
# Updating learning rate to 1.3493665047050212e-05
# Epoch: 2 cost time: 3.855191469192505
# Validation KL div loss: 0.559821
# Validation KL div loss: 0.560118
# Epoch: 2, Steps: 17 | Train Loss: 0.5714119 Vali Loss: 0.5598215 Test Loss: 0.5601183
# Validation loss decreased (0.590370 --> 0.559821).  Saving model ...
# Updating learning rate to 6.746832523525106e-06
# Epoch: 3 cost time: 3.8620147705078125
# Validation KL div loss: 0.545779
# Validation KL div loss: 0.548654
# Epoch: 3, Steps: 17 | Train Loss: 0.5425134 Vali Loss: 0.5457786 Test Loss: 0.5486537
# Validation loss decreased (0.559821 --> 0.545779).  Saving model ...
# Updating learning rate to 3.373416261762553e-06
# Epoch: 4 cost time: 3.8748271465301514
# Validation KL div loss: 0.537227
# Validation KL div loss: 0.537566
# Epoch: 4, Steps: 17 | Train Loss: 0.5354382 Vali Loss: 0.5372266 Test Loss: 0.5375661
# Validation loss decreased (0.545779 --> 0.537227).  Saving model ...
# Updating learning rate to 1.6867081308812765e-06
# Epoch: 5 cost time: 3.8067233562469482
# Validation KL div loss: 0.534534
# Validation KL div loss: 0.540732
# Epoch: 5, Steps: 17 | Train Loss: 0.5290566 Vali Loss: 0.5345345 Test Loss: 0.5407325
# Validation loss decreased (0.537227 --> 0.534534).  Saving model ...
# Updating learning rate to 8.433540654406383e-07
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 1155
# test shape: (1155, 1, 16) (1155, 1, 16)
# test shape: (1155, 1, 16) (1155, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial1_val20/H1_BOCsubset_trial1_val20_hyperparameters.json
# [INFO] Validation Score: 0.5345344692468643
# [INFO] Training finished with metrics: {'val_score': 0.5345344692468643}
# Namespace(cell='H1', train_chroms=[3, 20], val_chroms=[21], test_chroms=[21], setting='H1_BOCsubset_trial1_val21', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=2, d_layers=3, d_model=256, n_heads=4, d_ff=512, dropout=0.2960404353430677, learning_rate=1.3493665047050212e-05, weight_decay=0.0005258226479500629, factor=5, seq_len=64, batch_size=256, label_len=32, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 4949
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 623
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 623
# Epoch: 1 cost time: 4.295724153518677
# Validation KL div loss: 0.599384
# Validation KL div loss: 0.571124
# Epoch: 1, Steps: 19 | Train Loss: 0.6418693 Vali Loss: 0.5993841 Test Loss: 0.5711237
# Validation loss decreased (inf --> 0.599384).  Saving model ...
# Updating learning rate to 1.3493665047050212e-05
# Epoch: 2 cost time: 4.2566094398498535
# Validation KL div loss: 0.508139
# Validation KL div loss: 0.501209
# Epoch: 2, Steps: 19 | Train Loss: 0.5675625 Vali Loss: 0.5081395 Test Loss: 0.5012085
# Validation loss decreased (0.599384 --> 0.508139).  Saving model ...
# Updating learning rate to 6.746832523525106e-06
# Epoch: 3 cost time: 4.2930967807769775
# Validation KL div loss: 0.482102
# Validation KL div loss: 0.456101
# Epoch: 3, Steps: 19 | Train Loss: 0.5446970 Vali Loss: 0.4821016 Test Loss: 0.4561011
# Validation loss decreased (0.508139 --> 0.482102).  Saving model ...
# Updating learning rate to 3.373416261762553e-06
# Epoch: 4 cost time: 4.317922830581665
# Validation KL div loss: 0.476235
# Validation KL div loss: 0.465963
# Epoch: 4, Steps: 19 | Train Loss: 0.5400266 Vali Loss: 0.4762347 Test Loss: 0.4659631
# Validation loss decreased (0.482102 --> 0.476235).  Saving model ...
# Updating learning rate to 1.6867081308812765e-06
# Epoch: 5 cost time: 4.26978611946106
# Validation KL div loss: 0.492566
# Validation KL div loss: 0.449609
# Epoch: 5, Steps: 19 | Train Loss: 0.5318807 Vali Loss: 0.4925658 Test Loss: 0.4496089
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 8.433540654406383e-07
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 623
# test shape: (623, 1, 16) (623, 1, 16)
# test shape: (623, 1, 16) (623, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial1_val21/H1_BOCsubset_trial1_val21_hyperparameters.json
# [INFO] Validation Score: 0.47623470425605774
# [INFO] Training finished with metrics: {'val_score': 0.47623470425605774}
# [I 2025-11-26 00:52:24,251] Trial 1 finished with value: 0.5301907126392637 and parameters: {'e_layers': 2, 'd_layers': 3, 'd_model': 256, 'n_heads': 4, 'd_ff': 512, 'dropout': 0.2960404353430677, 'learning_rate': 1.3493665047050212e-05, 'weight_decay': 0.0005258226479500629, 'factor': 5, 'seq_len': 64}. Best is trial 0 with value: 0.1509270392132528.
# Namespace(cell='H1', train_chroms=[12, 21], val_chroms=[1], test_chroms=[1], setting='H1_BOCsubset_trial2_val1', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=1, d_layers=1, d_model=256, n_heads=8, d_ff=512, dropout=0.2934073900706347, learning_rate=8.282553226163598e-05, weight_decay=0.00328732803264943, factor=3, seq_len=128, batch_size=256, label_len=64, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 3147
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 4381
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 4381
# Epoch: 1 cost time: 1.705543041229248
# Validation KL div loss: 0.584613
# Validation KL div loss: 0.588986
# Epoch: 1, Steps: 12 | Train Loss: 0.6755501 Vali Loss: 0.5846132 Test Loss: 0.5889858
# Validation loss decreased (inf --> 0.584613).  Saving model ...
# Updating learning rate to 8.282553226163598e-05
# Epoch: 2 cost time: 1.67966890335083
# Validation KL div loss: 0.555544
# Validation KL div loss: 0.583173
# Epoch: 2, Steps: 12 | Train Loss: 0.5910712 Vali Loss: 0.5555439 Test Loss: 0.5831727
# Validation loss decreased (0.584613 --> 0.555544).  Saving model ...
# Updating learning rate to 4.141276613081799e-05
# Epoch: 3 cost time: 1.6808884143829346
# Validation KL div loss: 0.550393
# Validation KL div loss: 0.563131
# Epoch: 3, Steps: 12 | Train Loss: 0.5629259 Vali Loss: 0.5503934 Test Loss: 0.5631308
# Validation loss decreased (0.555544 --> 0.550393).  Saving model ...
# Updating learning rate to 2.0706383065408994e-05
# Epoch: 4 cost time: 1.7216119766235352
# Validation KL div loss: 0.547484
# Validation KL div loss: 0.564457
# Epoch: 4, Steps: 12 | Train Loss: 0.5501726 Vali Loss: 0.5474844 Test Loss: 0.5644566
# Validation loss decreased (0.550393 --> 0.547484).  Saving model ...
# Updating learning rate to 1.0353191532704497e-05
# Epoch: 5 cost time: 1.6979663372039795
# Validation KL div loss: 0.545568
# Validation KL div loss: 0.561350
# Epoch: 5, Steps: 12 | Train Loss: 0.5481515 Vali Loss: 0.5455685 Test Loss: 0.5613501
# Validation loss decreased (0.547484 --> 0.545568).  Saving model ...
# Updating learning rate to 5.176595766352249e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 4381
# test shape: (4381, 1, 16) (4381, 1, 16)
# test shape: (4381, 1, 16) (4381, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial2_val1/H1_BOCsubset_trial2_val1_hyperparameters.json
# [INFO] Validation Score: 0.5455684731988346
# [INFO] Training finished with metrics: {'val_score': 0.5455684731988346}
# Namespace(cell='H1', train_chroms=[1, 21], val_chroms=[12], test_chroms=[12], setting='H1_BOCsubset_trial2_val12', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=1, d_layers=1, d_model=256, n_heads=8, d_ff=512, dropout=0.2934073900706347, learning_rate=8.282553226163598e-05, weight_decay=0.00328732803264943, factor=3, seq_len=128, batch_size=256, label_len=64, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 5068
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 2460
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 2460
# Epoch: 1 cost time: 2.5791819095611572
# Validation KL div loss: 0.543624
# Validation KL div loss: 0.547264
# Epoch: 1, Steps: 19 | Train Loss: 0.6198508 Vali Loss: 0.5436245 Test Loss: 0.5472643
# Validation loss decreased (inf --> 0.543624).  Saving model ...
# Updating learning rate to 8.282553226163598e-05
# Epoch: 2 cost time: 2.575113296508789
# Validation KL div loss: 0.531049
# Validation KL div loss: 0.537495
# Epoch: 2, Steps: 19 | Train Loss: 0.5523964 Vali Loss: 0.5310486 Test Loss: 0.5374946
# Validation loss decreased (0.543624 --> 0.531049).  Saving model ...
# Updating learning rate to 4.141276613081799e-05
# Epoch: 3 cost time: 2.5838301181793213
# Validation KL div loss: 0.515402
# Validation KL div loss: 0.529458
# Epoch: 3, Steps: 19 | Train Loss: 0.5338125 Vali Loss: 0.5154023 Test Loss: 0.5294585
# Validation loss decreased (0.531049 --> 0.515402).  Saving model ...
# Updating learning rate to 2.0706383065408994e-05
# Epoch: 4 cost time: 2.572028398513794
# Validation KL div loss: 0.502055
# Validation KL div loss: 0.513496
# Epoch: 4, Steps: 19 | Train Loss: 0.5230824 Vali Loss: 0.5020546 Test Loss: 0.5134964
# Validation loss decreased (0.515402 --> 0.502055).  Saving model ...
# Updating learning rate to 1.0353191532704497e-05
# Epoch: 5 cost time: 2.5767688751220703
# Validation KL div loss: 0.507742
# Validation KL div loss: 0.512882
# Epoch: 5, Steps: 19 | Train Loss: 0.5181039 Vali Loss: 0.5077422 Test Loss: 0.5128823
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 5.176595766352249e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 2460
# test shape: (2460, 1, 16) (2460, 1, 16)
# test shape: (2460, 1, 16) (2460, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial2_val12/H1_BOCsubset_trial2_val12_hyperparameters.json
# [INFO] Validation Score: 0.5020546085304685
# [INFO] Training finished with metrics: {'val_score': 0.5020546085304685}
# Namespace(cell='H1', train_chroms=[1, 12], val_chroms=[21], test_chroms=[21], setting='H1_BOCsubset_trial2_val21', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=1, d_layers=1, d_model=256, n_heads=8, d_ff=512, dropout=0.2934073900706347, learning_rate=8.282553226163598e-05, weight_decay=0.00328732803264943, factor=3, seq_len=128, batch_size=256, label_len=64, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 6969
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 559
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 559
# Epoch: 1 cost time: 3.6171815395355225
# Validation KL div loss: 0.526966
# Validation KL div loss: 0.435621
# Epoch: 1, Steps: 27 | Train Loss: 0.6011456 Vali Loss: 0.5269664 Test Loss: 0.4356213
# Validation loss decreased (inf --> 0.526966).  Saving model ...
# Updating learning rate to 8.282553226163598e-05
# Epoch: 2 cost time: 3.585639715194702
# Validation KL div loss: 0.470538
# Validation KL div loss: 0.407660
# Epoch: 2, Steps: 27 | Train Loss: 0.5341396 Vali Loss: 0.4705382 Test Loss: 0.4076599
# Validation loss decreased (0.526966 --> 0.470538).  Saving model ...
# Updating learning rate to 4.141276613081799e-05
# Epoch: 3 cost time: 3.6383092403411865
# Validation KL div loss: 0.406725
# Validation KL div loss: 0.341330
# Epoch: 3, Steps: 27 | Train Loss: 0.4916374 Vali Loss: 0.4067254 Test Loss: 0.3413300
# Validation loss decreased (0.470538 --> 0.406725).  Saving model ...
# Updating learning rate to 2.0706383065408994e-05
# Epoch: 4 cost time: 3.5793521404266357
# Validation KL div loss: 0.336011
# Validation KL div loss: 0.291089
# Epoch: 4, Steps: 27 | Train Loss: 0.4468924 Vali Loss: 0.3360110 Test Loss: 0.2910889
# Validation loss decreased (0.406725 --> 0.336011).  Saving model ...
# Updating learning rate to 1.0353191532704497e-05
# Epoch: 5 cost time: 3.630472421646118
# Validation KL div loss: 0.314036
# Validation KL div loss: 0.266757
# Epoch: 5, Steps: 27 | Train Loss: 0.4125641 Vali Loss: 0.3140358 Test Loss: 0.2667572
# Validation loss decreased (0.336011 --> 0.314036).  Saving model ...
# Updating learning rate to 5.176595766352249e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 559
# test shape: (559, 1, 16) (559, 1, 16)
# test shape: (559, 1, 16) (559, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial2_val21/H1_BOCsubset_trial2_val21_hyperparameters.json
# [INFO] Validation Score: 0.3140357881784439
# [INFO] Training finished with metrics: {'val_score': 0.3140357881784439}
# [I 2025-11-26 00:53:31,671] Trial 2 finished with value: 0.453886289969249 and parameters: {'e_layers': 1, 'd_layers': 1, 'd_model': 256, 'n_heads': 8, 'd_ff': 512, 'dropout': 0.2934073900706347, 'learning_rate': 8.282553226163598e-05, 'weight_decay': 0.00328732803264943, 'factor': 3, 'seq_len': 128}. Best is trial 0 with value: 0.1509270392132528.
# Namespace(cell='H1', train_chroms=[20, 21], val_chroms=[4], test_chroms=[4], setting='H1_BOCsubset_trial3_val4', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=1, d_model=1024, n_heads=2, d_ff=1024, dropout=0.11616936638970309, learning_rate=0.00010383169826529597, weight_decay=0.0024223714603023145, factor=7, seq_len=32, batch_size=256, label_len=16, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 1874
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 3684
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 3684
# Epoch: 1 cost time: 2.093291997909546
# Validation KL div loss: 0.464305
# Validation KL div loss: 0.465580
# Epoch: 1, Steps: 7 | Train Loss: 0.5291430 Vali Loss: 0.4643054 Test Loss: 0.4655804
# Validation loss decreased (inf --> 0.464305).  Saving model ...
# Updating learning rate to 0.00010383169826529597
# Epoch: 2 cost time: 2.0610909461975098
# Validation KL div loss: 0.349807
# Validation KL div loss: 0.353570
# Epoch: 2, Steps: 7 | Train Loss: 0.3258747 Vali Loss: 0.3498070 Test Loss: 0.3535701
# Validation loss decreased (0.464305 --> 0.349807).  Saving model ...
# Updating learning rate to 5.1915849132647985e-05
# Epoch: 3 cost time: 2.0817410945892334
# Validation KL div loss: 0.323734
# Validation KL div loss: 0.328226
# Epoch: 3, Steps: 7 | Train Loss: 0.2300667 Vali Loss: 0.3237337 Test Loss: 0.3282255
# Validation loss decreased (0.349807 --> 0.323734).  Saving model ...
# Updating learning rate to 2.5957924566323992e-05
# Epoch: 4 cost time: 2.061920166015625
# Validation KL div loss: 0.328657
# Validation KL div loss: 0.334982
# Epoch: 4, Steps: 7 | Train Loss: 0.1942187 Vali Loss: 0.3286574 Test Loss: 0.3349816
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.2978962283161996e-05
# Epoch: 5 cost time: 2.052269220352173
# Validation KL div loss: 0.297667
# Validation KL div loss: 0.303602
# Epoch: 5, Steps: 7 | Train Loss: 0.1785317 Vali Loss: 0.2976670 Test Loss: 0.3036017
# Validation loss decreased (0.323734 --> 0.297667).  Saving model ...
# Updating learning rate to 6.489481141580998e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 3684
# test shape: (3684, 1, 16) (3684, 1, 16)
# test shape: (3684, 1, 16) (3684, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial3_val4/H1_BOCsubset_trial3_val4_hyperparameters.json
# [INFO] Validation Score: 0.29766697117260527
# [INFO] Training finished with metrics: {'val_score': 0.29766697117260527}
# Namespace(cell='H1', train_chroms=[4, 21], val_chroms=[20], test_chroms=[20], setting='H1_BOCsubset_trial3_val20', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=1, d_model=1024, n_heads=2, d_ff=1024, dropout=0.11616936638970309, learning_rate=0.00010383169826529597, weight_decay=0.0024223714603023145, factor=7, seq_len=32, batch_size=256, label_len=16, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 4371
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 1187
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 1187
# Epoch: 1 cost time: 4.78858494758606
# Validation KL div loss: 0.263650
# Validation KL div loss: 0.279470
# Epoch: 1, Steps: 17 | Train Loss: 0.3914552 Vali Loss: 0.2636496 Test Loss: 0.2794695
# Validation loss decreased (inf --> 0.263650).  Saving model ...
# Updating learning rate to 0.00010383169826529597
# Epoch: 2 cost time: 4.803969860076904
# Validation KL div loss: 0.184248
# Validation KL div loss: 0.192374
# Epoch: 2, Steps: 17 | Train Loss: 0.1564935 Vali Loss: 0.1842482 Test Loss: 0.1923742
# Validation loss decreased (0.263650 --> 0.184248).  Saving model ...
# Updating learning rate to 5.1915849132647985e-05
# Epoch: 3 cost time: 4.797386646270752
# Validation KL div loss: 0.170754
# Validation KL div loss: 0.179365
# Epoch: 3, Steps: 17 | Train Loss: 0.1186435 Vali Loss: 0.1707542 Test Loss: 0.1793648
# Validation loss decreased (0.184248 --> 0.170754).  Saving model ...
# Updating learning rate to 2.5957924566323992e-05
# Epoch: 4 cost time: 4.822638750076294
# Validation KL div loss: 0.153329
# Validation KL div loss: 0.168734
# Epoch: 4, Steps: 17 | Train Loss: 0.1046729 Vali Loss: 0.1533286 Test Loss: 0.1687336
# Validation loss decreased (0.170754 --> 0.153329).  Saving model ...
# Updating learning rate to 1.2978962283161996e-05
# Epoch: 5 cost time: 4.810370683670044
# Validation KL div loss: 0.160204
# Validation KL div loss: 0.168624
# Epoch: 5, Steps: 17 | Train Loss: 0.1018007 Vali Loss: 0.1602040 Test Loss: 0.1686235
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.489481141580998e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 1187
# test shape: (1187, 1, 16) (1187, 1, 16)
# test shape: (1187, 1, 16) (1187, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial3_val20/H1_BOCsubset_trial3_val20_hyperparameters.json
# [INFO] Validation Score: 0.1533285789191723
# [INFO] Training finished with metrics: {'val_score': 0.1533285789191723}
# Namespace(cell='H1', train_chroms=[4, 20], val_chroms=[21], test_chroms=[21], setting='H1_BOCsubset_trial3_val21', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=1, d_model=1024, n_heads=2, d_ff=1024, dropout=0.11616936638970309, learning_rate=0.00010383169826529597, weight_decay=0.0024223714603023145, factor=7, seq_len=32, batch_size=256, label_len=16, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 4903
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 655
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 655
# Epoch: 1 cost time: 5.389976501464844
# Validation KL div loss: 0.163398
# Validation KL div loss: 0.165204
# Epoch: 1, Steps: 19 | Train Loss: 0.3483979 Vali Loss: 0.1633976 Test Loss: 0.1652039
# Validation loss decreased (inf --> 0.163398).  Saving model ...
# Updating learning rate to 0.00010383169826529597
# Epoch: 2 cost time: 5.358659982681274
# Validation KL div loss: 0.114889
# Validation KL div loss: 0.115195
# Epoch: 2, Steps: 19 | Train Loss: 0.1478603 Vali Loss: 0.1148886 Test Loss: 0.1151953
# Validation loss decreased (0.163398 --> 0.114889).  Saving model ...
# Updating learning rate to 5.1915849132647985e-05
# Epoch: 3 cost time: 5.376083135604858
# Validation KL div loss: 0.106676
# Validation KL div loss: 0.104267
# Epoch: 3, Steps: 19 | Train Loss: 0.1110530 Vali Loss: 0.1066759 Test Loss: 0.1042670
# Validation loss decreased (0.114889 --> 0.106676).  Saving model ...
# Updating learning rate to 2.5957924566323992e-05
# Epoch: 4 cost time: 5.361780166625977
# Validation KL div loss: 0.103045
# Validation KL div loss: 0.102298
# Epoch: 4, Steps: 19 | Train Loss: 0.0989084 Vali Loss: 0.1030445 Test Loss: 0.1022976
# Validation loss decreased (0.106676 --> 0.103045).  Saving model ...
# Updating learning rate to 1.2978962283161996e-05
# Epoch: 5 cost time: 5.346533298492432
# Validation KL div loss: 0.097296
# Validation KL div loss: 0.100865
# Epoch: 5, Steps: 19 | Train Loss: 0.0953721 Vali Loss: 0.0972959 Test Loss: 0.1008647
# Validation loss decreased (0.103045 --> 0.097296).  Saving model ...
# Updating learning rate to 6.489481141580998e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 655
# test shape: (655, 1, 16) (655, 1, 16)
# test shape: (655, 1, 16) (655, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial3_val21/H1_BOCsubset_trial3_val21_hyperparameters.json
# [INFO] Validation Score: 0.0972958616912365
# [INFO] Training finished with metrics: {'val_score': 0.0972958616912365}
# [I 2025-11-26 00:55:14,978] Trial 3 finished with value: 0.18276380392767133 and parameters: {'e_layers': 3, 'd_layers': 1, 'd_model': 1024, 'n_heads': 2, 'd_ff': 1024, 'dropout': 0.11616936638970309, 'learning_rate': 0.00010383169826529597, 'weight_decay': 0.0024223714603023145, 'factor': 7, 'seq_len': 32}. Best is trial 0 with value: 0.1509270392132528.
# Namespace(cell='H1', train_chroms=[15, 21], val_chroms=[4], test_chroms=[4], setting='H1_BOCsubset_trial4_val4', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=2, d_layers=3, d_model=512, n_heads=2, d_ff=2048, dropout=0.11157319798640551, learning_rate=7.201374480265137e-05, weight_decay=0.00013644404207495254, factor=7, seq_len=32, batch_size=256, label_len=16, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 2186
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 3684
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 3684
# Epoch: 1 cost time: 2.139944553375244
# Validation KL div loss: 0.467644
# Validation KL div loss: 0.468366
# Epoch: 1, Steps: 8 | Train Loss: 0.5525388 Vali Loss: 0.4676443 Test Loss: 0.4683665
# Validation loss decreased (inf --> 0.467644).  Saving model ...
# Updating learning rate to 7.201374480265137e-05
# Epoch: 2 cost time: 2.0798470973968506
# Validation KL div loss: 0.381035
# Validation KL div loss: 0.381169
# Epoch: 2, Steps: 8 | Train Loss: 0.4072343 Vali Loss: 0.3810354 Test Loss: 0.3811688
# Validation loss decreased (0.467644 --> 0.381035).  Saving model ...
# Updating learning rate to 3.600687240132569e-05
# Epoch: 3 cost time: 2.083944082260132
# Validation KL div loss: 0.300849
# Validation KL div loss: 0.302170
# Epoch: 3, Steps: 8 | Train Loss: 0.3203958 Vali Loss: 0.3008488 Test Loss: 0.3021701
# Validation loss decreased (0.381035 --> 0.300849).  Saving model ...
# Updating learning rate to 1.8003436200662843e-05
# Epoch: 4 cost time: 2.087475299835205
# Validation KL div loss: 0.265840
# Validation KL div loss: 0.268186
# Epoch: 4, Steps: 8 | Train Loss: 0.2688336 Vali Loss: 0.2658395 Test Loss: 0.2681864
# Validation loss decreased (0.300849 --> 0.265840).  Saving model ...
# Updating learning rate to 9.001718100331422e-06
# Epoch: 5 cost time: 2.0903806686401367
# Validation KL div loss: 0.248564
# Validation KL div loss: 0.249871
# Epoch: 5, Steps: 8 | Train Loss: 0.2412299 Vali Loss: 0.2485644 Test Loss: 0.2498711
# Validation loss decreased (0.265840 --> 0.248564).  Saving model ...
# Updating learning rate to 4.500859050165711e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 3684
# test shape: (3684, 1, 16) (3684, 1, 16)
# test shape: (3684, 1, 16) (3684, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial4_val4/H1_BOCsubset_trial4_val4_hyperparameters.json
# [INFO] Validation Score: 0.2485644295811653
# [INFO] Training finished with metrics: {'val_score': 0.2485644295811653}
# Namespace(cell='H1', train_chroms=[4, 21], val_chroms=[15], test_chroms=[15], setting='H1_BOCsubset_trial4_val15', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=2, d_layers=3, d_model=512, n_heads=2, d_ff=2048, dropout=0.11157319798640551, learning_rate=7.201374480265137e-05, weight_decay=0.00013644404207495254, factor=7, seq_len=32, batch_size=256, label_len=16, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 4371
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 1499
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 1499
# Epoch: 1 cost time: 4.377209663391113
# Validation KL div loss: 0.352519
# Validation KL div loss: 0.349763
# Epoch: 1, Steps: 17 | Train Loss: 0.4556385 Vali Loss: 0.3525189 Test Loss: 0.3497634
# Validation loss decreased (inf --> 0.352519).  Saving model ...
# Updating learning rate to 7.201374480265137e-05
# Epoch: 2 cost time: 4.353748321533203
# Validation KL div loss: 0.179654
# Validation KL div loss: 0.181493
# Epoch: 2, Steps: 17 | Train Loss: 0.2162092 Vali Loss: 0.1796544 Test Loss: 0.1814933
# Validation loss decreased (0.352519 --> 0.179654).  Saving model ...
# Updating learning rate to 3.600687240132569e-05
# Epoch: 3 cost time: 4.341792345046997
# Validation KL div loss: 0.148808
# Validation KL div loss: 0.147176
# Epoch: 3, Steps: 17 | Train Loss: 0.1370168 Vali Loss: 0.1488081 Test Loss: 0.1471762
# Validation loss decreased (0.179654 --> 0.148808).  Saving model ...
# Updating learning rate to 1.8003436200662843e-05
# Epoch: 4 cost time: 4.360530376434326
# Validation KL div loss: 0.140979
# Validation KL div loss: 0.139431
# Epoch: 4, Steps: 17 | Train Loss: 0.1218229 Vali Loss: 0.1409790 Test Loss: 0.1394312
# Validation loss decreased (0.148808 --> 0.140979).  Saving model ...
# Updating learning rate to 9.001718100331422e-06
# Epoch: 5 cost time: 4.36508846282959
# Validation KL div loss: 0.136366
# Validation KL div loss: 0.135466
# Epoch: 5, Steps: 17 | Train Loss: 0.1130649 Vali Loss: 0.1363664 Test Loss: 0.1354662
# Validation loss decreased (0.140979 --> 0.136366).  Saving model ...
# Updating learning rate to 4.500859050165711e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 1499
# test shape: (1499, 1, 16) (1499, 1, 16)
# test shape: (1499, 1, 16) (1499, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial4_val15/H1_BOCsubset_trial4_val15_hyperparameters.json
# [INFO] Validation Score: 0.13636641204357147
# [INFO] Training finished with metrics: {'val_score': 0.13636641204357147}
# Namespace(cell='H1', train_chroms=[4, 15], val_chroms=[21], test_chroms=[21], setting='H1_BOCsubset_trial4_val21', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=2, d_layers=3, d_model=512, n_heads=2, d_ff=2048, dropout=0.11157319798640551, learning_rate=7.201374480265137e-05, weight_decay=0.00013644404207495254, factor=7, seq_len=32, batch_size=256, label_len=16, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 5215
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 655
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 655
# Epoch: 1 cost time: 5.125118017196655
# Validation KL div loss: 0.255678
# Validation KL div loss: 0.259231
# Epoch: 1, Steps: 20 | Train Loss: 0.4462934 Vali Loss: 0.2556781 Test Loss: 0.2592306
# Validation loss decreased (inf --> 0.255678).  Saving model ...
# Updating learning rate to 7.201374480265137e-05
# Epoch: 2 cost time: 5.105807781219482
# Validation KL div loss: 0.135118
# Validation KL div loss: 0.139341
# Epoch: 2, Steps: 20 | Train Loss: 0.2011355 Vali Loss: 0.1351179 Test Loss: 0.1393414
# Validation loss decreased (0.255678 --> 0.135118).  Saving model ...
# Updating learning rate to 3.600687240132569e-05
# Epoch: 3 cost time: 5.10382866859436
# Validation KL div loss: 0.114154
# Validation KL div loss: 0.121459
# Epoch: 3, Steps: 20 | Train Loss: 0.1322331 Vali Loss: 0.1141537 Test Loss: 0.1214594
# Validation loss decreased (0.135118 --> 0.114154).  Saving model ...
# Updating learning rate to 1.8003436200662843e-05
# Epoch: 4 cost time: 5.075666427612305
# Validation KL div loss: 0.115585
# Validation KL div loss: 0.115596
# Epoch: 4, Steps: 20 | Train Loss: 0.1152999 Vali Loss: 0.1155852 Test Loss: 0.1155958
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 9.001718100331422e-06
# Epoch: 5 cost time: 5.070289611816406
# Validation KL div loss: 0.103486
# Validation KL div loss: 0.112364
# Epoch: 5, Steps: 20 | Train Loss: 0.1108243 Vali Loss: 0.1034856 Test Loss: 0.1123637
# Validation loss decreased (0.114154 --> 0.103486).  Saving model ...
# Updating learning rate to 4.500859050165711e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 655
# test shape: (655, 1, 16) (655, 1, 16)
# test shape: (655, 1, 16) (655, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial4_val21/H1_BOCsubset_trial4_val21_hyperparameters.json
# [INFO] Validation Score: 0.1034855954349041
# [INFO] Training finished with metrics: {'val_score': 0.1034855954349041}
# [I 2025-11-26 00:56:47,017] Trial 4 finished with value: 0.1628054790198803 and parameters: {'e_layers': 2, 'd_layers': 3, 'd_model': 512, 'n_heads': 2, 'd_ff': 2048, 'dropout': 0.11157319798640551, 'learning_rate': 7.201374480265137e-05, 'weight_decay': 0.00013644404207495254, 'factor': 7, 'seq_len': 32}. Best is trial 0 with value: 0.1509270392132528.
#
# [✓] Best Hyperparameters Found:
#   e_layers: 3
#   d_layers: 1
#   d_model: 512
#   n_heads: 2
#   d_ff: 1024
#   dropout: 0.06333956530584388
#   learning_rate: 0.00015221846086499398
#   weight_decay: 0.0008830462059621119
#   factor: 5
#   seq_len: 32
# [✓] Saved Optuna BOC trials to: optuna_BOC_H1.csv

# %%
# !ls
# Out:
# dataset_feature_selection.ipynb  README.md
# iTransformer			 soffritto
# optuna_BOC_H1.csv		 transofritto
# optuna_informer_BOC.ipynb	 wavelet_informer.ipynb
# PatchTST

# %%
# !cat optuna_BOC_H1.csv
# Out:
# number,value,datetime_start,datetime_complete,duration,params_d_ff,params_d_layers,params_d_model,params_dropout,params_e_layers,params_factor,params_learning_rate,params_n_heads,params_seq_len,params_weight_decay,state
# 0,0.1509270392132528,2025-11-26 00:50:07.442310,2025-11-26 00:51:09.388707,0 days 00:01:01.946397,1024,1,512,0.06333956530584388,3,5,0.00015221846086499398,2,32,0.0008830462059621119,COMPLETE
# 1,0.5301907126392637,2025-11-26 00:51:09.389400,2025-11-26 00:52:24.251703,0 days 00:01:14.862303,512,3,256,0.2960404353430677,2,5,1.3493665047050212e-05,4,64,0.0005258226479500629,COMPLETE
# 2,0.453886289969249,2025-11-26 00:52:24.252271,2025-11-26 00:53:31.671477,0 days 00:01:07.419206,512,1,256,0.2934073900706347,1,3,8.282553226163598e-05,8,128,0.00328732803264943,COMPLETE
# 3,0.18276380392767133,2025-11-26 00:53:31.672040,2025-11-26 00:55:14.978077,0 days 00:01:43.306037,1024,1,1024,0.11616936638970309,3,7,0.00010383169826529597,2,32,0.0024223714603023145,COMPLETE
# 4,0.1628054790198803,2025-11-26 00:55:14.978522,2025-11-26 00:56:47.017664,0 days 00:01:32.039142,2048,3,512,0.11157319798640551,2,7,7.201374480265137e-05,2,32,0.00013644404207495254,COMPLETE
