# %% [markdown]
# <a href="https://colab.research.google.com/github/utkuayten/CS401-soffritto/blob/main/optuna_informer_BOC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install optuna
# !git clone https://github.com/utkuayten/CS401-soffritto
# Out:
# Collecting optuna
#   Downloading optuna-4.6.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.2)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.6.0-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 12.3 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.6.0
# Cloning into 'CS401-soffritto'...
# remote: Enumerating objects: 1608, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 1608 (delta 47), reused 59 (delta 30), pack-reused 1524 (from 2)
# Receiving objects: 100% (1608/1608), 764.69 MiB | 32.11 MiB/s, done.
# Resolving deltas: 100% (870/870), done.
# Updating files: 100% (432/432), done.

# %%
# %cd CS401-soffritto/
# Out:
# /content/CS401-soffritto

# %%
# !python3 transofritto/optuna_BOC.py --cell H1 --n_trials 10 --group_size 5
# Out:
# [I 2025-11-25 22:11:47,305] A new study created in memory with name: no-name-89a1f86f-72a8-4148-ab73-c60fd4ab07f3
# Namespace(cell='H1', train_chroms=[9, 11, 18, 22], val_chroms=[4], test_chroms=[4], setting='H1_BOCsubset_trial0_val4', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=3, d_model=256, n_heads=8, d_ff=1024, dropout=0.1617247050134421, learning_rate=1.34380600151982e-05, weight_decay=0.0053655621992263125, factor=7, seq_len=64, batch_size=256, label_len=32, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# Namespace(cell='H1', train_chroms=[10, 11, 18, 21], val_chroms=[2], test_chroms=[2], setting='H1_BOCsubset_trial1_val2', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=1, d_layers=2, d_model=1024, n_heads=4, d_ff=1024, dropout=0.13150162777457663, learning_rate=1.2460675472400335e-05, weight_decay=3.999442442629561e-06, factor=5, seq_len=32, batch_size=256, label_len=16, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Namespace(cell='H1', train_chroms=[10, 15, 17, 22], val_chroms=[2], test_chroms=[2], setting='H1_BOCsubset_trial3_val2', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=1, d_model=256, n_heads=4, d_ff=2048, dropout=0.16439740997439395, learning_rate=0.00015402222825357023, weight_decay=0.0006251750873159532, factor=3, seq_len=64, batch_size=256, label_len=32, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# [WAVELET/MODEL] OFF
# Use GPU: cuda:0
# Namespace(cell='H1', train_chroms=[6, 11, 18, 21], val_chroms=[1], test_chroms=[1], setting='H1_BOCsubset_trial2_val1', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=1, d_model=256, n_heads=4, d_ff=2048, dropout=0.1407034592668811, learning_rate=0.00010687831258231931, weight_decay=0.00299455581732519, factor=7, seq_len=128, batch_size=256, label_len=64, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# [WAVELET/MODEL] OFF
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 7355
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 6316
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 7986
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 6907
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 4599
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 4381
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 4567
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 3652
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 4599
# test 4381
# test 3652
# test 4567
# Epoch: 1 cost time: 24.13395595550537
# Validation KL div loss: 0.614495
# Validation KL div loss: 0.620951
# Epoch: 1, Steps: 26 | Train Loss: 0.6450788 Vali Loss: 0.6144949 Test Loss: 0.6209506
# Validation loss decreased (inf --> 0.614495).  Saving model ...
# Epoch: 1 cost time: 27.15212845802307
# Updating learning rate to 1.34380600151982e-05
# Epoch: 1 cost time: 28.583924770355225
# Validation KL div loss: 0.493371
# Validation KL div loss: 0.511532
# Epoch: 1, Steps: 31 | Train Loss: 0.5674800 Vali Loss: 0.4933711 Test Loss: 0.5115321
# Validation loss decreased (inf --> 0.493371).  Saving model ...
# Updating learning rate to 0.00010687831258231931
# Validation KL div loss: 0.420928
# Validation KL div loss: 0.421687
# Epoch: 1, Steps: 24 | Train Loss: 0.5255938 Vali Loss: 0.4209282 Test Loss: 0.4216867
# Validation loss decreased (inf --> 0.420928).  Saving model ...
# Updating learning rate to 0.00015402222825357023
# Epoch: 1 cost time: 44.57402944564819
# Validation KL div loss: 0.449551
# Validation KL div loss: 0.453552
# Epoch: 1, Steps: 28 | Train Loss: 0.5193393 Vali Loss: 0.4495506 Test Loss: 0.4535524
# Validation loss decreased (inf --> 0.449551).  Saving model ...
# Epoch: 2 cost time: 20.79439067840576
# Updating learning rate to 1.2460675472400335e-05
# Validation KL div loss: 0.564568
# Validation KL div loss: 0.567670
# Epoch: 2, Steps: 26 | Train Loss: 0.5432028 Vali Loss: 0.5645682 Test Loss: 0.5676703
# Validation loss decreased (0.614495 --> 0.564568).  Saving model ...
# Updating learning rate to 6.7190300075991e-06
# Epoch: 2 cost time: 28.439522743225098
# Validation KL div loss: 0.173324
# Validation KL div loss: 0.181815
# Epoch: 2, Steps: 31 | Train Loss: 0.3056519 Vali Loss: 0.1733237 Test Loss: 0.1818150
# Validation loss decreased (0.493371 --> 0.173324).  Saving model ...
# Updating learning rate to 5.3439156291159655e-05
# Epoch: 3 cost time: 16.86704730987549
# Validation KL div loss: 0.556209
# Validation KL div loss: 0.561157
# Epoch: 3, Steps: 26 | Train Loss: 0.5190081 Vali Loss: 0.5562088 Test Loss: 0.5611565
# Validation loss decreased (0.564568 --> 0.556209).  Saving model ...
# Updating learning rate to 3.35951500379955e-06
# Epoch: 2 cost time: 39.9871883392334
# Validation KL div loss: 0.147381
# Validation KL div loss: 0.148194
# Epoch: 2, Steps: 24 | Train Loss: 0.2507724 Vali Loss: 0.1473814 Test Loss: 0.1481945
# Validation loss decreased (0.420928 --> 0.147381).  Saving model ...
# Updating learning rate to 7.701111412678511e-05
# Epoch: 4 cost time: 14.99872374534607
# Validation KL div loss: 0.551707
# Validation KL div loss: 0.557241
# Epoch: 4, Steps: 26 | Train Loss: 0.5097264 Vali Loss: 0.5517067 Test Loss: 0.5572409
# Validation loss decreased (0.556209 --> 0.551707).  Saving model ...
# Updating learning rate to 1.679757501899775e-06
# Epoch: 3 cost time: 25.7827889919281
# Validation KL div loss: 0.149133
# Validation KL div loss: 0.155461
# Epoch: 3, Steps: 31 | Train Loss: 0.1672535 Vali Loss: 0.1491325 Test Loss: 0.1554611
# Validation loss decreased (0.173324 --> 0.149133).  Saving model ...
# Updating learning rate to 2.6719578145579828e-05
# Epoch: 5 cost time: 17.470458030700684
# Validation KL div loss: 0.549291
# Validation KL div loss: 0.549088
# Epoch: 5, Steps: 26 | Train Loss: 0.5077814 Vali Loss: 0.5492913 Test Loss: 0.5490879
# Validation loss decreased (0.551707 --> 0.549291).  Saving model ...
# Updating learning rate to 8.398787509498875e-07
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 3652
# Epoch: 3 cost time: 36.729215145111084
# Validation KL div loss: 0.134482
# Validation KL div loss: 0.137112
# Epoch: 3, Steps: 24 | Train Loss: 0.1617138 Vali Loss: 0.1344824 Test Loss: 0.1371118
# Validation loss decreased (0.147381 --> 0.134482).  Saving model ...
# Updating learning rate to 3.850555706339256e-05
# test shape: (3652, 1, 16) (3652, 1, 16)
# test shape: (3652, 1, 16) (3652, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial0_val4/H1_BOCsubset_trial0_val4_hyperparameters.json
# [INFO] Validation Score: 0.5492912828922272
# [INFO] Training finished with metrics: {'val_score': 0.5492912828922272}
# Namespace(cell='H1', train_chroms=[4, 11, 18, 22], val_chroms=[9], test_chroms=[9], setting='H1_BOCsubset_trial0_val9', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=3, d_model=256, n_heads=8, d_ff=1024, dropout=0.1617247050134421, learning_rate=1.34380600151982e-05, weight_decay=0.0053655621992263125, factor=7, seq_len=64, batch_size=256, label_len=32, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 8419
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 2140
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 2140
# Epoch: 4 cost time: 29.173003673553467
# Validation KL div loss: 0.129047
# Validation KL div loss: 0.134292
# Epoch: 4, Steps: 31 | Train Loss: 0.1455231 Vali Loss: 0.1290474 Test Loss: 0.1342919
# Validation loss decreased (0.149133 --> 0.129047).  Saving model ...
# Updating learning rate to 1.3359789072789914e-05
# Epoch: 1 cost time: 19.69716167449951
# Validation KL div loss: 0.517546
# Validation KL div loss: 0.512478
# Epoch: 1, Steps: 32 | Train Loss: 0.6554826 Vali Loss: 0.5175462 Test Loss: 0.5124782
# Validation loss decreased (inf --> 0.517546).  Saving model ...
# Updating learning rate to 1.34380600151982e-05
# Epoch: 4 cost time: 36.97046399116516
# Validation KL div loss: 0.122394
# Epoch: 5 cost time: 25.265163898468018
# Epoch: 2 cost time: 109.04606771469116
# Validation KL div loss: 0.120495
# Epoch: 4, Steps: 24 | Train Loss: 0.1430403 Vali Loss: 0.1223935 Test Loss: 0.1204949
# Validation loss decreased (0.134482 --> 0.122394).  Saving model ...
# Updating learning rate to 1.925277853169628e-05
# Validation KL div loss: 0.310733
# Validation KL div loss: 0.125334
# Validation KL div loss: 0.320406
# Epoch: 2, Steps: 28 | Train Loss: 0.3820013 Vali Loss: 0.3107330 Test Loss: 0.3204062
# Validation loss decreased (0.449551 --> 0.310733).  Saving model ...
# Updating learning rate to 6.230337736200167e-06
# Validation KL div loss: 0.128860
# Epoch: 5, Steps: 31 | Train Loss: 0.1384792 Vali Loss: 0.1253337 Test Loss: 0.1288604
# Validation loss decreased (0.129047 --> 0.125334).  Saving model ...
# Updating learning rate to 6.679894536394957e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 4381
# test shape: (4381, 1, 16) (4381, 1, 16)
# test shape: (4381, 1, 16) (4381, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial2_val1/H1_BOCsubset_trial2_val1_hyperparameters.json
# [INFO] Validation Score: 0.12533373823937247
# [INFO] Training finished with metrics: {'val_score': 0.12533373823937247}
# Namespace(cell='H1', train_chroms=[1, 11, 18, 21], val_chroms=[6], test_chroms=[6], setting='H1_BOCsubset_trial2_val6', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=1, d_model=256, n_heads=4, d_ff=2048, dropout=0.1407034592668811, learning_rate=0.00010687831258231931, weight_decay=0.00299455581732519, factor=7, seq_len=128, batch_size=256, label_len=64, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 9153
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 3214
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 3214
# Epoch: 2 cost time: 33.82257390022278
# Validation KL div loss: 0.480984
# Validation KL div loss: 0.470032
# Epoch: 2, Steps: 32 | Train Loss: 0.5635943 Vali Loss: 0.4809844 Test Loss: 0.4700322
# Validation loss decreased (0.517546 --> 0.480984).  Saving model ...
# Updating learning rate to 6.7190300075991e-06
# Epoch: 5 cost time: 39.82801628112793
# Validation KL div loss: 0.114392
# Validation KL div loss: 0.116660
# Epoch: 5, Steps: 24 | Train Loss: 0.1380642 Vali Loss: 0.1143920 Test Loss: 0.1166595
# Validation loss decreased (0.122394 --> 0.114392).  Saving model ...
# Updating learning rate to 9.62638926584814e-06
# Epoch: 3 cost time: 17.51729655265808
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 4567
# Validation KL div loss: 0.472218
# Validation KL div loss: 0.468905
# Epoch: 3, Steps: 32 | Train Loss: 0.5454552 Vali Loss: 0.4722179 Test Loss: 0.4689050
# Validation loss decreased (0.480984 --> 0.472218).  Saving model ...
# Updating learning rate to 3.35951500379955e-06
# test shape: (4567, 1, 16) (4567, 1, 16)
# test shape: (4567, 1, 16) (4567, 1, 16)
# Epoch: 1 cost time: 30.35961627960205
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial3_val2/H1_BOCsubset_trial3_val2_hyperparameters.json
# [INFO] Validation Score: 0.11439198036404218
# [INFO] Training finished with metrics: {'val_score': 0.11439198036404218}
# Namespace(cell='H1', train_chroms=[2, 15, 17, 22], val_chroms=[10], test_chroms=[10], setting='H1_BOCsubset_trial3_val10', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=1, d_model=256, n_heads=4, d_ff=2048, dropout=0.16439740997439395, learning_rate=0.00015402222825357023, weight_decay=0.0006251750873159532, factor=3, seq_len=64, batch_size=256, label_len=32, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# Validation KL div loss: 0.426278
# train 8332
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 2551
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 2551
# Validation KL div loss: 0.423732
# Epoch: 1, Steps: 35 | Train Loss: 0.5535458 Vali Loss: 0.4262778 Test Loss: 0.4237317
# Validation loss decreased (inf --> 0.426278).  Saving model ...
# Updating learning rate to 0.00010687831258231931
# Epoch: 4 cost time: 25.651939392089844
# Validation KL div loss: 0.470787
# Validation KL div loss: 0.462547
# Epoch: 4, Steps: 32 | Train Loss: 0.5351733 Vali Loss: 0.4707866 Test Loss: 0.4625475
# Validation loss decreased (0.472218 --> 0.470787).  Saving model ...
# Updating learning rate to 1.679757501899775e-06
# Epoch: 3 cost time: 71.78026366233826
# Validation KL div loss: 0.242046
# Validation KL div loss: 0.241935
# Epoch: 3, Steps: 28 | Train Loss: 0.2854913 Vali Loss: 0.2420464 Test Loss: 0.2419348
# Validation loss decreased (0.310733 --> 0.242046).  Saving model ...
# Updating learning rate to 3.1151688681000837e-06
# Epoch: 2 cost time: 29.853702306747437
# Validation KL div loss: 0.164075
# Validation KL div loss: 0.160827
# Epoch: 2, Steps: 35 | Train Loss: 0.2663959 Vali Loss: 0.1640746 Test Loss: 0.1608267
# Validation loss decreased (0.426278 --> 0.164075).  Saving model ...
# Updating learning rate to 5.3439156291159655e-05
# Epoch: 5 cost time: 22.37739086151123
# Validation KL div loss: 0.465315
# Validation KL div loss: 0.462632
# Epoch: 5, Steps: 32 | Train Loss: 0.5321076 Vali Loss: 0.4653148 Test Loss: 0.4626315
# Validation loss decreased (0.470787 --> 0.465315).  Saving model ...
# Updating learning rate to 8.398787509498875e-07
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 2140
# test shape: (2140, 1, 16) (2140, 1, 16)
# test shape: (2140, 1, 16) (2140, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial0_val9/H1_BOCsubset_trial0_val9_hyperparameters.json
# [INFO] Validation Score: 0.4653148204088211
# [INFO] Training finished with metrics: {'val_score': 0.4653148204088211}
# Namespace(cell='H1', train_chroms=[4, 9, 18, 22], val_chroms=[11], test_chroms=[11], setting='H1_BOCsubset_trial0_val11', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=3, d_model=256, n_heads=8, d_ff=1024, dropout=0.1617247050134421, learning_rate=1.34380600151982e-05, weight_decay=0.0053655621992263125, factor=7, seq_len=64, batch_size=256, label_len=32, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 8016
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 2543
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# Epoch: 1 cost time: 51.020641565322876
# test 2543
# Validation KL div loss: 0.263608
# Validation KL div loss: 0.259904
# Epoch: 1, Steps: 32 | Train Loss: 0.5117463 Vali Loss: 0.2636079 Test Loss: 0.2599041
# Validation loss decreased (inf --> 0.263608).  Saving model ...
# Updating learning rate to 0.00015402222825357023
# Epoch: 3 cost time: 30.234158515930176
# Validation KL div loss: 0.136077
# Validation KL div loss: 0.134484
# Epoch: 3, Steps: 35 | Train Loss: 0.1607863 Vali Loss: 0.1360766 Test Loss: 0.1344837
# Validation loss decreased (0.164075 --> 0.136077).  Saving model ...
# Updating learning rate to 2.6719578145579828e-05
# Epoch: 1 cost time: 18.98902201652527
# Validation KL div loss: 0.556428
# Validation KL div loss: 0.553837
# Epoch: 1, Steps: 31 | Train Loss: 0.6446335 Vali Loss: 0.5564285 Test Loss: 0.5538371
# Validation loss decreased (inf --> 0.556428).  Saving model ...
# Updating learning rate to 1.34380600151982e-05
# Epoch: 2 cost time: 15.381280422210693
# Validation KL div loss: 0.521940
# Validation KL div loss: 0.522705
# Epoch: 2, Steps: 31 | Train Loss: 0.5624617 Vali Loss: 0.5219402 Test Loss: 0.5227048
# Validation loss decreased (0.556428 --> 0.521940).  Saving model ...
# Updating learning rate to 6.7190300075991e-06
# Epoch: 4 cost time: 28.14104199409485
# Validation KL div loss: 0.131199
# Validation KL div loss: 0.129710
# Epoch: 4, Steps: 35 | Train Loss: 0.1434338 Vali Loss: 0.1311985 Test Loss: 0.1297096
# Validation loss decreased (0.136077 --> 0.131199).  Saving model ...
# Updating learning rate to 1.3359789072789914e-05
# Epoch: 2 cost time: 50.71223998069763
# Validation KL div loss: 0.121643
# Validation KL div loss: 0.122785
# Epoch: 2, Steps: 32 | Train Loss: 0.1901239 Vali Loss: 0.1216430 Test Loss: 0.1227851
# Validation loss decreased (0.263608 --> 0.121643).  Saving model ...
# Updating learning rate to 7.701111412678511e-05
# Epoch: 4 cost time: 82.95589351654053
# Validation KL div loss: 0.217017
# Validation KL div loss: 0.219139
# Epoch: 4, Steps: 28 | Train Loss: 0.2422896 Vali Loss: 0.2170172 Test Loss: 0.2191387
# Validation loss decreased (0.242046 --> 0.217017).  Saving model ...
# Updating learning rate to 1.5575844340500419e-06
# Epoch: 3 cost time: 22.994523525238037
# Validation KL div loss: 0.512351
# Validation KL div loss: 0.515049
# Epoch: 3, Steps: 31 | Train Loss: 0.5398346 Vali Loss: 0.5123510 Test Loss: 0.5150491
# Validation loss decreased (0.521940 --> 0.512351).  Saving model ...
# Updating learning rate to 3.35951500379955e-06
# Epoch: 5 cost time: 32.08458685874939
# Validation KL div loss: 0.129319
# Epoch: 4 cost time: 17.267370462417603
# Validation KL div loss: 0.126366
# Epoch: 5, Steps: 35 | Train Loss: 0.1370289 Vali Loss: 0.1293192 Test Loss: 0.1263659
# Validation loss decreased (0.131199 --> 0.129319).  Saving model ...
# Validation KL div loss: 0.510837
# Updating learning rate to 6.679894536394957e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 3214
# Validation KL div loss: 0.506884
# Epoch: 4, Steps: 31 | Train Loss: 0.5308824 Vali Loss: 0.5108373 Test Loss: 0.5068843
# Validation loss decreased (0.512351 --> 0.510837).  Saving model ...
# Updating learning rate to 1.679757501899775e-06
# test shape: (3214, 1, 16) (3214, 1, 16)
# test shape: (3214, 1, 16) (3214, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial2_val6/H1_BOCsubset_trial2_val6_hyperparameters.json
# [INFO] Validation Score: 0.12931917421519756
# [INFO] Training finished with metrics: {'val_score': 0.12931917421519756}
# Namespace(cell='H1', train_chroms=[1, 6, 18, 21], val_chroms=[11], test_chroms=[11], setting='H1_BOCsubset_trial2_val11', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=1, d_model=256, n_heads=4, d_ff=2048, dropout=0.1407034592668811, learning_rate=0.00010687831258231931, weight_decay=0.00299455581732519, factor=7, seq_len=128, batch_size=256, label_len=64, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 9888
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 2479
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 2479
# Epoch: 3 cost time: 49.832275390625
# Validation KL div loss: 0.112114
# Validation KL div loss: 0.109963
# Epoch: 3, Steps: 32 | Train Loss: 0.1342153 Vali Loss: 0.1121141 Test Loss: 0.1099628
# Validation loss decreased (0.121643 --> 0.112114).  Saving model ...
# Updating learning rate to 3.850555706339256e-05
# Epoch: 5 cost time: 23.377455472946167
# Validation KL div loss: 0.509629
# Validation KL div loss: 0.509828
# Epoch: 5, Steps: 31 | Train Loss: 0.5282010 Vali Loss: 0.5096293 Test Loss: 0.5098284
# Validation loss decreased (0.510837 --> 0.509629).  Saving model ...
# Updating learning rate to 8.398787509498875e-07
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 2543
# test shape: (2543, 1, 16) (2543, 1, 16)
# test shape: (2543, 1, 16) (2543, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial0_val11/H1_BOCsubset_trial0_val11_hyperparameters.json
# [INFO] Validation Score: 0.5096292528841231
# [INFO] Training finished with metrics: {'val_score': 0.5096292528841231}
# Namespace(cell='H1', train_chroms=[4, 9, 11, 22], val_chroms=[18], test_chroms=[18], setting='H1_BOCsubset_trial0_val18', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=3, d_model=256, n_heads=8, d_ff=1024, dropout=0.1617247050134421, learning_rate=1.34380600151982e-05, weight_decay=0.0053655621992263125, factor=7, seq_len=64, batch_size=256, label_len=32, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 9145
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 1414
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 1414
# Epoch: 1 cost time: 31.682499408721924
# Validation KL div loss: 0.434305
# Validation KL div loss: 0.428675
# Epoch: 1, Steps: 38 | Train Loss: 0.5430458 Vali Loss: 0.4343047 Test Loss: 0.4286748
# Validation loss decreased (inf --> 0.434305).  Saving model ...
# Updating learning rate to 0.00010687831258231931
# Epoch: 1 cost time: 19.803905963897705
# Validation KL div loss: 0.548299
# Validation KL div loss: 0.539062
# Epoch: 1, Steps: 35 | Train Loss: 0.6414286 Vali Loss: 0.5482992 Test Loss: 0.5390620
# Validation loss decreased (inf --> 0.548299).  Saving model ...
# Updating learning rate to 1.34380600151982e-05
# Epoch: 5 cost time: 84.41321063041687
# Validation KL div loss: 0.205740
# Validation KL div loss: 0.206577
# Epoch: 5, Steps: 28 | Train Loss: 0.2251114 Vali Loss: 0.2057397 Test Loss: 0.2065774
# Validation loss decreased (0.217017 --> 0.205740).  Saving model ...
# Updating learning rate to 7.787922170250209e-07
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 4599
# Epoch: 4 cost time: 46.1441285610199
# test shape: (4599, 1, 16) (4599, 1, 16)
# test shape: (4599, 1, 16) (4599, 1, 16)
# Validation KL div loss: 0.102883
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial1_val2/H1_BOCsubset_trial1_val2_hyperparameters.json
# [INFO] Validation Score: 0.20573965503888972
# [INFO] Training finished with metrics: {'val_score': 0.20573965503888972}
# Validation KL div loss: 0.102827
# Namespace(cell='H1', train_chroms=[2, 11, 18, 21], val_chroms=[10], test_chroms=[10], setting='H1_BOCsubset_trial1_val10', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=1, d_layers=2, d_model=1024, n_heads=4, d_ff=1024, dropout=0.13150162777457663, learning_rate=1.2460675472400335e-05, weight_decay=3.999442442629561e-06, factor=5, seq_len=32, batch_size=256, label_len=16, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# Epoch: 4, Steps: 32 | Train Loss: 0.1222425 Vali Loss: 0.1028831 Test Loss: 0.1028271
# Validation loss decreased (0.112114 --> 0.102883).  Saving model ...
# Updating learning rate to 1.925277853169628e-05
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 9371
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 2583
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 2583
# Epoch: 2 cost time: 39.34883999824524
# Validation KL div loss: 0.137121
# Validation KL div loss: 0.136442
# Epoch: 2, Steps: 38 | Train Loss: 0.2360299 Vali Loss: 0.1371215 Test Loss: 0.1364416
# Validation loss decreased (0.434305 --> 0.137121).  Saving model ...
# Updating learning rate to 5.3439156291159655e-05
# Epoch: 2 cost time: 31.589791774749756
# Validation KL div loss: 0.526079
# Validation KL div loss: 0.508807
# Epoch: 2, Steps: 35 | Train Loss: 0.5475167 Vali Loss: 0.5260793 Test Loss: 0.5088075
# Validation loss decreased (0.548299 --> 0.526079).  Saving model ...
# Updating learning rate to 6.7190300075991e-06
# Epoch: 3 cost time: 16.701754093170166
# Validation KL div loss: 0.504949
# Validation KL div loss: 0.487025
# Epoch: 3, Steps: 35 | Train Loss: 0.5288598 Vali Loss: 0.5049493 Test Loss: 0.4870248
# Validation loss decreased (0.526079 --> 0.504949).  Saving model ...
# Updating learning rate to 3.35951500379955e-06
# Epoch: 3 cost time: 28.89505171775818
# Validation KL div loss: 0.117766
# Validation KL div loss: 0.121466
# Epoch: 3, Steps: 38 | Train Loss: 0.1432705 Vali Loss: 0.1177658 Test Loss: 0.1214656
# Validation loss decreased (0.137121 --> 0.117766).  Saving model ...
# Updating learning rate to 2.6719578145579828e-05
# Epoch: 4 cost time: 18.94671392440796
# Validation KL div loss: 0.504052
# Validation KL div loss: 0.486685
# Epoch: 4, Steps: 35 | Train Loss: 0.5224044 Vali Loss: 0.5040521 Test Loss: 0.4866846
# Validation loss decreased (0.504949 --> 0.504052).  Saving model ...
# Updating learning rate to 1.679757501899775e-06
# Epoch: 1 cost time: 64.02149677276611
# Validation KL div loss: 0.364749
# Validation KL div loss: 0.348431
# Epoch: 1, Steps: 36 | Train Loss: 0.4985557 Vali Loss: 0.3647487 Test Loss: 0.3484305
# Validation loss decreased (inf --> 0.364749).  Saving model ...
# Updating learning rate to 1.2460675472400335e-05
# Epoch: 5 cost time: 18.334920644760132
# Epoch: 4 cost time: 31.057186126708984
# Validation KL div loss: 0.499186
# Validation KL div loss: 0.106432
# Validation KL div loss: 0.489024
# Epoch: 5, Steps: 35 | Train Loss: 0.5192315 Vali Loss: 0.4991857 Test Loss: 0.4890243
# Validation loss decreased (0.504052 --> 0.499186).  Saving model ...
# Updating learning rate to 8.398787509498875e-07
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 1414
# Validation KL div loss: 0.109304
# Epoch: 4, Steps: 38 | Train Loss: 0.1289884 Vali Loss: 0.1064324 Test Loss: 0.1093043
# Validation loss decreased (0.117766 --> 0.106432).  Saving model ...
# Updating learning rate to 1.3359789072789914e-05
# test shape: (1414, 1, 16) (1414, 1, 16)
# test shape: (1414, 1, 16) (1414, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial0_val18/H1_BOCsubset_trial0_val18_hyperparameters.json
# [INFO] Validation Score: 0.49918570518493655
# [INFO] Training finished with metrics: {'val_score': 0.49918570518493655}
# Namespace(cell='H1', train_chroms=[4, 9, 11, 18], val_chroms=[22], test_chroms=[22], setting='H1_BOCsubset_trial0_val22', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=3, d_model=256, n_heads=8, d_ff=1024, dropout=0.1617247050134421, learning_rate=1.34380600151982e-05, weight_decay=0.0053655621992263125, factor=7, seq_len=64, batch_size=256, label_len=32, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 9941
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 618
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 618
# Epoch: 1 cost time: 18.045633792877197
# Validation KL div loss: 0.452321
# Validation KL div loss: 0.497133
# Epoch: 1, Steps: 38 | Train Loss: 0.6239637 Vali Loss: 0.4523213 Test Loss: 0.4971331
# Validation loss decreased (inf --> 0.452321).  Saving model ...
# Updating learning rate to 1.34380600151982e-05
# Epoch: 5 cost time: 28.661564350128174
# Validation KL div loss: 0.105403
# Validation KL div loss: 0.105788
# Epoch: 5, Steps: 38 | Train Loss: 0.1231822 Vali Loss: 0.1054025 Test Loss: 0.1057883
# Validation loss decreased (0.106432 --> 0.105403).  Saving model ...
# Updating learning rate to 6.679894536394957e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 2479
# test shape: (2479, 1, 16) (2479, 1, 16)
# test shape: (2479, 1, 16) (2479, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial2_val11/H1_BOCsubset_trial2_val11_hyperparameters.json
# [INFO] Validation Score: 0.10540252592828539
# [INFO] Training finished with metrics: {'val_score': 0.10540252592828539}
# Namespace(cell='H1', train_chroms=[1, 6, 11, 21], val_chroms=[18], test_chroms=[18], setting='H1_BOCsubset_trial2_val18', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=1, d_model=256, n_heads=4, d_ff=2048, dropout=0.1407034592668811, learning_rate=0.00010687831258231931, weight_decay=0.00299455581732519, factor=7, seq_len=128, batch_size=256, label_len=64, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 11017
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 1350
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 1350
# Epoch: 2 cost time: 57.07546615600586
# Validation KL div loss: 0.208439
# Validation KL div loss: 0.201433
# Epoch: 2, Steps: 36 | Train Loss: 0.3256001 Vali Loss: 0.2084393 Test Loss: 0.2014333
# Validation loss decreased (0.364749 --> 0.208439).  Saving model ...
# Updating learning rate to 6.230337736200167e-06
# Epoch: 2 cost time: 26.465798377990723
# Validation KL div loss: 0.431877
# Validation KL div loss: 0.446820
# Epoch: 2, Steps: 38 | Train Loss: 0.5443557 Vali Loss: 0.4318774 Test Loss: 0.4468203
# Validation loss decreased (0.452321 --> 0.431877).  Saving model ...
# Updating learning rate to 6.7190300075991e-06
# Epoch: 3 cost time: 17.530574798583984
# Validation KL div loss: 0.412303
# Validation KL div loss: 0.457508
# Epoch: 3, Steps: 38 | Train Loss: 0.5250937 Vali Loss: 0.4123033 Test Loss: 0.4575082
# Validation loss decreased (0.431877 --> 0.412303).  Saving model ...
# Updating learning rate to 3.35951500379955e-06
# Epoch: 1 cost time: 34.22139573097229
# Validation KL div loss: 0.365279
# Validation KL div loss: 0.365879
# Epoch: 1, Steps: 43 | Train Loss: 0.5517739 Vali Loss: 0.3652788 Test Loss: 0.3658792
# Validation loss decreased (inf --> 0.365279).  Saving model ...
# Updating learning rate to 0.00010687831258231931
# Epoch: 4 cost time: 19.2921941280365
# Validation KL div loss: 0.413527
# Validation KL div loss: 0.459705
# Epoch: 4, Steps: 38 | Train Loss: 0.5181067 Vali Loss: 0.4135266 Test Loss: 0.4597048
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.679757501899775e-06
# Epoch: 2 cost time: 31.479336261749268
# Validation KL div loss: 0.105918
# Validation KL div loss: 0.104094
# Epoch: 2, Steps: 43 | Train Loss: 0.2119226 Vali Loss: 0.1059177 Test Loss: 0.1040942
# Validation loss decreased (0.365279 --> 0.105918).  Saving model ...
# Updating learning rate to 5.3439156291159655e-05
# Epoch: 5 cost time: 18.871647119522095
# Validation KL div loss: 0.413327
# Validation KL div loss: 0.428476
# Epoch: 5, Steps: 38 | Train Loss: 0.5157818 Vali Loss: 0.4133270 Test Loss: 0.4284755
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 8.398787509498875e-07
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# Epoch: 3 cost time: 62.77765369415283
# test 618
# Validation KL div loss: 0.164510
# test shape: (618, 1, 16) (618, 1, 16)
# test shape: (618, 1, 16) (618, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial0_val22/H1_BOCsubset_trial0_val22_hyperparameters.json
# [INFO] Validation Score: 0.41230326890945435
# [INFO] Training finished with metrics: {'val_score': 0.41230326890945435}
# [I 2025-11-25 22:22:09,473] Trial 0 finished with value: 0.48714486605591245 and parameters: {'e_layers': 3, 'd_layers': 3, 'd_model': 256, 'n_heads': 8, 'd_ff': 1024, 'dropout': 0.1617247050134421, 'learning_rate': 1.34380600151982e-05, 'weight_decay': 0.0053655621992263125, 'factor': 7, 'seq_len': 64}. Best is trial 0 with value: 0.48714486605591245.
# Namespace(cell='H1', train_chroms=[8, 11, 19, 22], val_chroms=[2], test_chroms=[2], setting='H1_BOCsubset_trial4_val2', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=2, d_layers=2, d_model=256, n_heads=2, d_ff=512, dropout=0.08182378539455125, learning_rate=1.9067600458231096e-05, weight_decay=0.0005495943385528983, factor=3, seq_len=32, batch_size=256, label_len=16, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# Validation KL div loss: 0.160171
# Epoch: 3, Steps: 36 | Train Loss: 0.2165499 Vali Loss: 0.1645100 Test Loss: 0.1601711
# Validation loss decreased (0.208439 --> 0.164510).  Saving model ...
# train 7142
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# Updating learning rate to 3.1151688681000837e-06
# val 4599
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 4599
# Epoch: 1 cost time: 8.05252718925476
# Validation KL div loss: 0.538033
# Validation KL div loss: 0.538839
# Epoch: 1, Steps: 27 | Train Loss: 0.6211117 Vali Loss: 0.5380329 Test Loss: 0.5388388
# Validation loss decreased (inf --> 0.538033).  Saving model ...
# Updating learning rate to 1.9067600458231096e-05
# Epoch: 2 cost time: 8.407828092575073
# Validation KL div loss: 0.496532
# Epoch: 3 cost time: 27.751054525375366
# Validation KL div loss: 0.093063
# Validation KL div loss: 0.497821
# Epoch: 2, Steps: 27 | Train Loss: 0.4787060 Vali Loss: 0.4965319 Test Loss: 0.4978214
# Validation loss decreased (0.538033 --> 0.496532).  Saving model ...
# Updating learning rate to 9.533800229115548e-06
# Validation KL div loss: 0.089904
# Epoch: 3, Steps: 43 | Train Loss: 0.1348226 Vali Loss: 0.0930629 Test Loss: 0.0899036
# Validation loss decreased (0.105918 --> 0.093063).  Saving model ...
# Updating learning rate to 2.6719578145579828e-05
# Epoch: 3 cost time: 8.272550106048584
# Validation KL div loss: 0.488237
# Validation KL div loss: 0.485762
# Epoch: 3, Steps: 27 | Train Loss: 0.4473946 Vali Loss: 0.4882368 Test Loss: 0.4857620
# Validation loss decreased (0.496532 --> 0.488237).  Saving model ...
# Updating learning rate to 4.766900114557774e-06
# Epoch: 4 cost time: 7.970982313156128
# Epoch: 4 cost time: 41.84829545021057
# Validation KL div loss: 0.476953
# Validation KL div loss: 0.154417
# Validation KL div loss: 0.150078
# Epoch: 4, Steps: 36 | Train Loss: 0.1838253 Vali Loss: 0.1544165 Test Loss: 0.1500780
# Validation loss decreased (0.164510 --> 0.154417).  Saving model ...
# Updating learning rate to 1.5575844340500419e-06
# Validation KL div loss: 0.475076
# Epoch: 4, Steps: 27 | Train Loss: 0.4369898 Vali Loss: 0.4769531 Test Loss: 0.4750760
# Validation loss decreased (0.488237 --> 0.476953).  Saving model ...
# Updating learning rate to 2.383450057278887e-06
# Epoch: 4 cost time: 26.401246070861816
# Validation KL div loss: 0.087309
# Validation KL div loss: 0.083274
# Epoch: 4, Steps: 43 | Train Loss: 0.1227232 Vali Loss: 0.0873094 Test Loss: 0.0832738
# Validation loss decreased (0.093063 --> 0.087309).  Saving model ...
# Updating learning rate to 1.3359789072789914e-05
# Epoch: 5 cost time: 9.45686149597168
# Validation KL div loss: 0.470425
# Validation KL div loss: 0.473365
# Epoch: 5, Steps: 27 | Train Loss: 0.4304096 Vali Loss: 0.4704246 Test Loss: 0.4733655
# Validation loss decreased (0.476953 --> 0.470425).  Saving model ...
# Updating learning rate to 1.1917250286394435e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 4599
# test shape: (4599, 1, 16) (4599, 1, 16)
# test shape: (4599, 1, 16) (4599, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial4_val2/H1_BOCsubset_trial4_val2_hyperparameters.json
# [INFO] Validation Score: 0.470424622297287
# [INFO] Training finished with metrics: {'val_score': 0.470424622297287}
# Namespace(cell='H1', train_chroms=[2, 11, 19, 22], val_chroms=[8], test_chroms=[8], setting='H1_BOCsubset_trial4_val8', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=2, d_layers=2, d_model=256, n_heads=2, d_ff=512, dropout=0.08182378539455125, learning_rate=1.9067600458231096e-05, weight_decay=0.0005495943385528983, factor=3, seq_len=32, batch_size=256, label_len=16, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 8970
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 2771
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 2771
# Epoch: 1 cost time: 10.391174554824829
# Validation KL div loss: 0.474382
# Validation KL div loss: 0.476441
# ...
# Epoch: 5, Steps: 30 | Train Loss: 0.0928948 Vali Loss: 0.1138514 Test Loss: 0.1126605
# Validation loss decreased (0.116398 --> 0.113851).  Saving model ...
# Updating learning rate to 1.787026554127982e-05
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 2551
# test shape: (2551, 1, 16) (2551, 1, 16)
# test shape: (2551, 1, 16) (2551, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial9_val10/H1_BOCsubset_trial9_val10_hyperparameters.json
# [INFO] Validation Score: 0.1138513974017567
# [INFO] Training finished with metrics: {'val_score': 0.1138513974017567}
# Namespace(cell='H1', train_chroms=[4, 10, 18, 21], val_chroms=[13], test_chroms=[13], setting='H1_BOCsubset_trial9_val13', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=2, d_layers=3, d_model=256, n_heads=4, d_ff=512, dropout=0.05027261059463613, learning_rate=0.00028592424866047715, weight_decay=8.019036659968358e-06, factor=7, seq_len=64, batch_size=256, label_len=32, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 8432
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 1857
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 1857
# Epoch: 1 cost time: 11.587534189224243
# Validation KL div loss: 0.164292
# Validation KL div loss: 0.169308
# Epoch: 1, Steps: 32 | Train Loss: 0.3864131 Vali Loss: 0.1642924 Test Loss: 0.1693079
# Validation loss decreased (inf --> 0.164292).  Saving model ...
# Updating learning rate to 0.00028592424866047715
# Epoch: 2 cost time: 11.485263347625732
# Validation KL div loss: 0.106248
# Epoch: 5 cost time: 50.936458110809326
# Validation KL div loss: 0.108226
# Epoch: 2, Steps: 32 | Train Loss: 0.1322118 Vali Loss: 0.1062479 Test Loss: 0.1082256
# Validation loss decreased (0.164292 --> 0.106248).  Saving model ...
# Updating learning rate to 0.00014296212433023857
# Validation KL div loss: 0.098005
# Validation KL div loss: 0.100425
# Epoch: 5, Steps: 36 | Train Loss: 0.1223198 Vali Loss: 0.0980049 Test Loss: 0.1004249
# Validation loss decreased (0.103759 --> 0.098005).  Saving model ...
# Updating learning rate to 2.994438564219961e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 623
# test shape: (623, 1, 16) (623, 1, 16)
# test shape: (623, 1, 16) (623, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial5_val21/H1_BOCsubset_trial5_val21_hyperparameters.json
# [INFO] Validation Score: 0.09800486266613007
# [INFO] Training finished with metrics: {'val_score': 0.09800486266613007}
# [I 2025-11-25 22:54:43,737] Trial 5 finished with value: 0.11735274288516777 and parameters: {'e_layers': 3, 'd_layers': 3, 'd_model': 1024, 'n_heads': 4, 'd_ff': 512, 'dropout': 0.20906537788743373, 'learning_rate': 4.791101702751938e-05, 'weight_decay': 2.478993060322644e-05, 'factor': 5, 'seq_len': 64}. Best is trial 6 with value: 0.09049775086725369.
# Epoch: 3 cost time: 13.988733053207397
# Validation KL div loss: 0.094311
# Validation KL div loss: 0.094326
# Epoch: 3, Steps: 32 | Train Loss: 0.0993173 Vali Loss: 0.0943111 Test Loss: 0.0943256
# Validation loss decreased (0.106248 --> 0.094311).  Saving model ...
# Updating learning rate to 7.148106216511929e-05
# Epoch: 2 cost time: 72.30618667602539
# Validation KL div loss: 0.156266
# Validation KL div loss: 0.161438
# Epoch: 2, Steps: 44 | Train Loss: 0.2827490 Vali Loss: 0.1562660 Test Loss: 0.1614379
# Validation loss decreased (0.303370 --> 0.156266).  Saving model ...
# Updating learning rate to 6.230337736200167e-06
# Epoch: 4 cost time: 11.206811428070068
# Validation KL div loss: 0.091538
# Validation KL div loss: 0.091469
# Epoch: 4, Steps: 32 | Train Loss: 0.0886685 Vali Loss: 0.0915375 Test Loss: 0.0914688
# Validation loss decreased (0.094311 --> 0.091538).  Saving model ...
# Updating learning rate to 3.574053108255964e-05
# Epoch: 3 cost time: 21.006019115447998
# Validation KL div loss: 0.130839
# Validation KL div loss: 0.130715
# Epoch: 3, Steps: 44 | Train Loss: 0.1808391 Vali Loss: 0.1308387 Test Loss: 0.1307148
# Validation loss decreased (0.156266 --> 0.130839).  Saving model ...
# Updating learning rate to 3.1151688681000837e-06
# Epoch: 5 cost time: 11.218383312225342
# Validation KL div loss: 0.088446
# Validation KL div loss: 0.087614
# Epoch: 5, Steps: 32 | Train Loss: 0.0854512 Vali Loss: 0.0884459 Test Loss: 0.0876140
# Validation loss decreased (0.091538 --> 0.088446).  Saving model ...
# Updating learning rate to 1.787026554127982e-05
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 1857
# test shape: (1857, 1, 16) (1857, 1, 16)
# test shape: (1857, 1, 16) (1857, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial9_val13/H1_BOCsubset_trial9_val13_hyperparameters.json
# [INFO] Validation Score: 0.08844593912363052
# [INFO] Training finished with metrics: {'val_score': 0.08844593912363052}
# Namespace(cell='H1', train_chroms=[4, 10, 13, 21], val_chroms=[18], test_chroms=[18], setting='H1_BOCsubset_trial9_val18', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=2, d_layers=3, d_model=256, n_heads=4, d_ff=512, dropout=0.05027261059463613, learning_rate=0.00028592424866047715, weight_decay=8.019036659968358e-06, factor=7, seq_len=64, batch_size=256, label_len=32, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 8875
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 1414
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 1414
# Epoch: 1 cost time: 11.243122100830078
# Validation KL div loss: 0.164436
# Validation KL div loss: 0.163823
# Epoch: 1, Steps: 34 | Train Loss: 0.4290982 Vali Loss: 0.1644361 Test Loss: 0.1638234
# Validation loss decreased (inf --> 0.164436).  Saving model ...
# Updating learning rate to 0.00028592424866047715
# Epoch: 4 cost time: 21.5435950756073
# Validation KL div loss: 0.118510
# Validation KL div loss: 0.128843
# Epoch: 4, Steps: 44 | Train Loss: 0.1596481 Vali Loss: 0.1185104 Test Loss: 0.1288430
# Validation loss decreased (0.130839 --> 0.118510).  Saving model ...
# Updating learning rate to 1.5575844340500419e-06
# Epoch: 2 cost time: 11.78887152671814
# Validation KL div loss: 0.100547
# Validation KL div loss: 0.097611
# Epoch: 2, Steps: 34 | Train Loss: 0.1372810 Vali Loss: 0.1005468 Test Loss: 0.0976114
# Validation loss decreased (0.164436 --> 0.100547).  Saving model ...
# Updating learning rate to 0.00014296212433023857
# Epoch: 5 cost time: 20.707727193832397
# Validation KL div loss: 0.129067
# Validation KL div loss: 0.121415
# Epoch: 5, Steps: 44 | Train Loss: 0.1528198 Vali Loss: 0.1290669 Test Loss: 0.1214146
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 7.787922170250209e-07
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 655
# Epoch: 3 cost time: 12.043318033218384
# test shape: (655, 1, 16) (655, 1, 16)
# test shape: (655, 1, 16) (655, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial1_val21/H1_BOCsubset_trial1_val21_hyperparameters.json
# [INFO] Validation Score: 0.1185104176402092
# [INFO] Training finished with metrics: {'val_score': 0.1185104176402092}
# [I 2025-11-25 22:56:04,147] Trial 1 finished with value: 0.15396926978055167 and parameters: {'e_layers': 1, 'd_layers': 2, 'd_model': 1024, 'n_heads': 4, 'd_ff': 1024, 'dropout': 0.13150162777457663, 'learning_rate': 1.2460675472400335e-05, 'weight_decay': 3.999442442629561e-06, 'factor': 5, 'seq_len': 32}. Best is trial 6 with value: 0.09049775086725369.
# Validation KL div loss: 0.090519
# Validation KL div loss: 0.086019
# Epoch: 3, Steps: 34 | Train Loss: 0.1034195 Vali Loss: 0.0905192 Test Loss: 0.0860192
# Validation loss decreased (0.100547 --> 0.090519).  Saving model ...
# Updating learning rate to 7.148106216511929e-05
# Epoch: 4 cost time: 8.078129529953003
# Validation KL div loss: 0.082190
# Validation KL div loss: 0.080937
# Epoch: 4, Steps: 34 | Train Loss: 0.0931867 Vali Loss: 0.0821899 Test Loss: 0.0809367
# Validation loss decreased (0.090519 --> 0.082190).  Saving model ...
# Updating learning rate to 3.574053108255964e-05
# Epoch: 5 cost time: 8.033478736877441
# Validation KL div loss: 0.079017
# Validation KL div loss: 0.076448
# Epoch: 5, Steps: 34 | Train Loss: 0.0875362 Vali Loss: 0.0790169 Test Loss: 0.0764476
# Validation loss decreased (0.082190 --> 0.079017).  Saving model ...
# Updating learning rate to 1.787026554127982e-05
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 1414
# test shape: (1414, 1, 16) (1414, 1, 16)
# test shape: (1414, 1, 16) (1414, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial9_val18/H1_BOCsubset_trial9_val18_hyperparameters.json
# [INFO] Validation Score: 0.07901686429977417
# [INFO] Training finished with metrics: {'val_score': 0.07901686429977417}
# Namespace(cell='H1', train_chroms=[4, 10, 13, 18], val_chroms=[21], test_chroms=[21], setting='H1_BOCsubset_trial9_val21', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=2, d_layers=3, d_model=256, n_heads=4, d_ff=512, dropout=0.05027261059463613, learning_rate=0.00028592424866047715, weight_decay=8.019036659968358e-06, factor=7, seq_len=64, batch_size=256, label_len=32, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 9666
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 623
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 623
# Epoch: 1 cost time: 8.74361252784729
# Validation KL div loss: 0.153946
# Validation KL div loss: 0.163861
# Epoch: 1, Steps: 37 | Train Loss: 0.3885012 Vali Loss: 0.1539456 Test Loss: 0.1638608
# Validation loss decreased (inf --> 0.153946).  Saving model ...
# Updating learning rate to 0.00028592424866047715
# Epoch: 2 cost time: 8.730613946914673
# Validation KL div loss: 0.101067
# Validation KL div loss: 0.110955
# Epoch: 2, Steps: 37 | Train Loss: 0.1264170 Vali Loss: 0.1010671 Test Loss: 0.1109552
# Validation loss decreased (0.153946 --> 0.101067).  Saving model ...
# Updating learning rate to 0.00014296212433023857
# Epoch: 3 cost time: 8.71086573600769
# Validation KL div loss: 0.085401
# Validation KL div loss: 0.093872
# Epoch: 3, Steps: 37 | Train Loss: 0.0962483 Vali Loss: 0.0854008 Test Loss: 0.0938721
# Validation loss decreased (0.101067 --> 0.085401).  Saving model ...
# Updating learning rate to 7.148106216511929e-05
# Epoch: 4 cost time: 8.661851167678833
# Validation KL div loss: 0.080129
# Validation KL div loss: 0.091538
# Epoch: 4, Steps: 37 | Train Loss: 0.0877336 Vali Loss: 0.0801289 Test Loss: 0.0915377
# Validation loss decreased (0.085401 --> 0.080129).  Saving model ...
# Updating learning rate to 3.574053108255964e-05
# Epoch: 5 cost time: 8.632866144180298
# Validation KL div loss: 0.084160
# Validation KL div loss: 0.088434
# Epoch: 5, Steps: 37 | Train Loss: 0.0841313 Vali Loss: 0.0841595 Test Loss: 0.0884339
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.787026554127982e-05
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 623
# test shape: (623, 1, 16) (623, 1, 16)
# test shape: (623, 1, 16) (623, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial9_val21/H1_BOCsubset_trial9_val21_hyperparameters.json
# [INFO] Validation Score: 0.08012891560792923
# [INFO] Training finished with metrics: {'val_score': 0.08012891560792923}
# [I 2025-11-25 22:57:14,851] Trial 9 finished with value: 0.0924327164297066 and parameters: {'e_layers': 2, 'd_layers': 3, 'd_model': 256, 'n_heads': 4, 'd_ff': 512, 'dropout': 0.05027261059463613, 'learning_rate': 0.00028592424866047715, 'weight_decay': 8.019036659968358e-06, 'factor': 7, 'seq_len': 64}. Best is trial 6 with value: 0.09049775086725369.
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/CS401-soffritto/transofritto/optuna_BOC.py", line 191, in <module>
#     main()
#   File "/content/CS401-soffritto/transofritto/optuna_BOC.py", line 169, in main
#     study.optimize(
#   File "/usr/local/lib/python3.12/dist-packages/optuna/study/study.py", line 490, in optimize
#     _optimize(
#   File "/usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py", line 86, in _optimize
#     with ThreadPoolExecutor(max_workers=n_jobs) as executor:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 647, in __exit__
#     self.shutdown(wait=True)
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 239, in shutdown
#     t.join()
#   File "/usr/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#   File "/usr/lib/python3.12/threading.py", line 1179, in _wait_for_tstate_lock
#     self._stop()
#   File "/usr/lib/python3.12/threading.py", line 1106, in _stop
#     _maintain_shutdown_locks()
#   File "/usr/lib/python3.12/threading.py", line 868, in _maintain_shutdown_locks
#     _shutdown_locks.difference_update(to_remove)
# KeyboardInterrupt
