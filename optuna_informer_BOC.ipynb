# %% [markdown]
# <a href="https://colab.research.google.com/github/utkuayten/CS401-soffritto/blob/main/optuna_informer_BOC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install optuna
# !git clone https://github.com/utkuayten/CS401-soffritto
# Out:
# Collecting optuna
#   Downloading optuna-4.6.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.2)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.6.0-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 12.6 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.6.0
# Cloning into 'CS401-soffritto'...
# remote: Enumerating objects: 1611, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 1611 (delta 48), reused 58 (delta 30), pack-reused 1524 (from 2)
# Receiving objects: 100% (1611/1611), 764.72 MiB | 48.29 MiB/s, done.
# Resolving deltas: 100% (871/871), done.
# Updating files: 100% (433/433), done.

# %%
# %cd CS401-soffritto/
import torch
print(torch.cuda.is_available())
# Out:
# /content/CS401-soffritto
# True

# %%
# !python3 transofritto/optuna_BOC.py --cell H1 --n_trials 10 --group_size 5
# Out:
# [I 2025-11-25 23:25:34,231] A new study created in memory with name: no-name-1bb9d3fe-6605-4979-a653-a60104d42de0
# Namespace(cell='H1', train_chroms=[9, 11, 18, 22], val_chroms=[4], test_chroms=[4], setting='H1_BOCsubset_trial0_val4', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=3, d_model=1024, n_heads=8, d_ff=1024, dropout=0.06265400903132286, learning_rate=7.49746040360264e-05, weight_decay=0.009391295083058939, factor=3, seq_len=32, batch_size=128, label_len=16, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# Namespace(cell='H1', train_chroms=[10, 11, 18, 21], val_chroms=[2], test_chroms=[2], setting='H1_BOCsubset_trial1_val2', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=2, d_layers=3, d_model=256, n_heads=8, d_ff=1024, dropout=0.2517254868415988, learning_rate=0.0003185544851500179, weight_decay=0.0010460683090809655, factor=5, seq_len=64, batch_size=128, label_len=32, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# Namespace(cell='H1', train_chroms=[6, 11, 18, 21], val_chroms=[1], test_chroms=[1], setting='H1_BOCsubset_trial2_val1', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=1, d_layers=2, d_model=512, n_heads=2, d_ff=2048, dropout=0.2650615512984011, learning_rate=4.276618710035313e-05, weight_decay=0.0001809330882459594, factor=7, seq_len=32, batch_size=128, label_len=16, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Namespace(cell='H1', train_chroms=[10, 15, 17, 22], val_chroms=[2], test_chroms=[2], setting='H1_BOCsubset_trial3_val2', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=3, d_model=1024, n_heads=2, d_ff=512, dropout=0.11276811281350484, learning_rate=0.0002744837184893825, weight_decay=1.474037573163214e-06, factor=7, seq_len=64, batch_size=128, label_len=32, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 8082
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 7323
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 4477
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 4567
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 6939
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 6316
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 4477
# test 4567
# val 4567
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 3684
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 4567
# test 3684
# Epoch: 1 cost time: 37.068915367126465
# Epoch: 1 cost time: 38.04884171485901
# Validation KL div loss: 0.196773
# Validation KL div loss: 0.196328
# Validation KL div loss: 0.129608
# Epoch: 1, Steps: 63 | Train Loss: 0.3755147 Vali Loss: 0.1967727 Test Loss: 0.1963280
# Validation loss decreased (inf --> 0.196773).  Saving model ...
# Updating learning rate to 4.276618710035313e-05
# Validation KL div loss: 0.126458
# Epoch: 1, Steps: 54 | Train Loss: 0.3244103 Vali Loss: 0.1296078 Test Loss: 0.1264584
# Validation loss decreased (inf --> 0.129608).  Saving model ...
# Updating learning rate to 7.49746040360264e-05
# Epoch: 1 cost time: 63.90028381347656
# Validation KL div loss: 0.159428
# Validation KL div loss: 0.159425
# Epoch: 1, Steps: 49 | Train Loss: 0.5278026 Vali Loss: 0.1594277 Test Loss: 0.1594248
# Validation loss decreased (inf --> 0.159428).  Saving model ...
# Updating learning rate to 0.0002744837184893825
# Epoch: 2 cost time: 38.250805139541626
# Validation KL div loss: 0.095451
# Validation KL div loss: 0.094624
# Epoch: 2, Steps: 54 | Train Loss: 0.1159896 Vali Loss: 0.0954510 Test Loss: 0.0946238
# Validation loss decreased (0.129608 --> 0.095451).  Saving model ...
# Updating learning rate to 3.74873020180132e-05
# Epoch: 2 cost time: 47.42521286010742
# Validation KL div loss: 0.133159
# Validation KL div loss: 0.132920
# Epoch: 2, Steps: 63 | Train Loss: 0.1704113 Vali Loss: 0.1331587 Test Loss: 0.1329202
# Validation loss decreased (0.196773 --> 0.133159).  Saving model ...
# Updating learning rate to 2.1383093550176566e-05
# Epoch: 1 cost time: 94.6950626373291
# Validation KL div loss: 0.172967
# Validation KL div loss: 0.173392
# Epoch: 1, Steps: 57 | Train Loss: 0.4002909 Vali Loss: 0.1729665 Test Loss: 0.1733919
# Validation loss decreased (inf --> 0.172967).  Saving model ...
# Updating learning rate to 0.0003185544851500179
# Epoch: 3 cost time: 35.34849500656128
# Validation KL div loss: 0.079545
# Epoch: 3 cost time: 34.887821435928345
# Validation KL div loss: 0.122850
# Validation KL div loss: 0.080166
# Epoch: 3, Steps: 54 | Train Loss: 0.0894940 Vali Loss: 0.0795452 Test Loss: 0.0801664
# Validation loss decreased (0.095451 --> 0.079545).  Saving model ...
# Updating learning rate to 1.87436510090066e-05
# Validation KL div loss: 0.122672
# Epoch: 3, Steps: 63 | Train Loss: 0.1391666 Vali Loss: 0.1228498 Test Loss: 0.1226725
# Validation loss decreased (0.133159 --> 0.122850).  Saving model ...
# Updating learning rate to 1.0691546775088283e-05
# Epoch: 2 cost time: 64.05871844291687
# Validation KL div loss: 0.139601
# Validation KL div loss: 0.142088
# Epoch: 2, Steps: 49 | Train Loss: 0.1575574 Vali Loss: 0.1396009 Test Loss: 0.1420882
# Validation loss decreased (0.159428 --> 0.139601).  Saving model ...
# Updating learning rate to 0.00013724185924469126
# Epoch: 4 cost time: 43.04462718963623
# Epoch: 4 cost time: 43.05195593833923
# Validation KL div loss: 0.077447
# Validation KL div loss: 0.118319
# Validation KL div loss: 0.077997
# Epoch: 4, Steps: 54 | Train Loss: 0.0798582 Vali Loss: 0.0774469 Test Loss: 0.0779975
# Validation loss decreased (0.079545 --> 0.077447).  Saving model ...
# Validation KL div loss: 0.118436
# Epoch: 4, Steps: 63 | Train Loss: 0.1310746 Vali Loss: 0.1183191 Test Loss: 0.1184361
# Validation loss decreased (0.122850 --> 0.118319).  Saving model ...
# Updating learning rate to 5.3457733875441414e-06
# Updating learning rate to 9.3718255045033e-06
# Epoch: 2 cost time: 102.07797598838806
# Validation KL div loss: 0.111267
# Validation KL div loss: 0.109700
# Epoch: 2, Steps: 57 | Train Loss: 0.1559115 Vali Loss: 0.1112671 Test Loss: 0.1096997
# Validation loss decreased (0.172967 --> 0.111267).  Saving model ...
# Updating learning rate to 0.00015927724257500895
# Epoch: 3 cost time: 60.964133739471436
# Validation KL div loss: 0.104088
# Epoch: 5 cost time: 43.67583513259888
# Validation KL div loss: 0.106793
# Epoch: 3, Steps: 49 | Train Loss: 0.1259498 Vali Loss: 0.1040882 Test Loss: 0.1067933
# Validation loss decreased (0.139601 --> 0.104088).  Saving model ...
# Updating learning rate to 6.862092962234563e-05
# Epoch: 5 cost time: 45.613529205322266
# Validation KL div loss: 0.074362
# Validation KL div loss: 0.114558
# Validation KL div loss: 0.115448
# Epoch: 5, Steps: 63 | Train Loss: 0.1271532 Vali Loss: 0.1145578 Test Loss: 0.1154483
# Validation loss decreased (0.118319 --> 0.114558).  Saving model ...
# Validation KL div loss: 0.074117
# Epoch: 5, Steps: 54 | Train Loss: 0.0753083 Vali Loss: 0.0743624 Test Loss: 0.0741168
# Validation loss decreased (0.077447 --> 0.074362).  Saving model ...
# Updating learning rate to 2.6728866937720707e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# Updating learning rate to 4.68591275225165e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 4477
# test 3684
# test shape: (4477, 1, 16) (4477, 1, 16)
# test shape: (4477, 1, 16) (4477, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial2_val1/H1_BOCsubset_trial2_val1_hyperparameters.json
# [INFO] Validation Score: 0.11455781626350739
# [INFO] Training finished with metrics: {'val_score': 0.11455781626350739}
# Namespace(cell='H1', train_chroms=[1, 11, 18, 21], val_chroms=[6], test_chroms=[6], setting='H1_BOCsubset_trial2_val6', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=1, d_layers=2, d_model=512, n_heads=2, d_ff=2048, dropout=0.2650615512984011, learning_rate=4.276618710035313e-05, weight_decay=0.0001809330882459594, factor=7, seq_len=32, batch_size=128, label_len=16, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 9249
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 3310
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 3310
# test shape: (3684, 1, 16) (3684, 1, 16)
# test shape: (3684, 1, 16) (3684, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial0_val4/H1_BOCsubset_trial0_val4_hyperparameters.json
# [INFO] Validation Score: 0.07436244056693145
# [INFO] Training finished with metrics: {'val_score': 0.07436244056693145}
# Namespace(cell='H1', train_chroms=[4, 11, 18, 22], val_chroms=[9], test_chroms=[9], setting='H1_BOCsubset_trial0_val9', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=3, d_model=1024, n_heads=8, d_ff=1024, dropout=0.06265400903132286, learning_rate=7.49746040360264e-05, weight_decay=0.009391295083058939, factor=3, seq_len=32, batch_size=128, label_len=16, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 8451
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 2172
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 2172
# Epoch: 4 cost time: 70.03156089782715
# Validation KL div loss: 0.098260
# Validation KL div loss: 0.098194
# Epoch: 4, Steps: 49 | Train Loss: 0.1085724 Vali Loss: 0.0982603 Test Loss: 0.0981939
# Validation loss decreased (0.104088 --> 0.098260).  Saving model ...
# Epoch: 1 cost time: 52.71087384223938
# Updating learning rate to 3.4310464811172816e-05
# Validation KL div loss: 0.203433
# Validation KL div loss: 0.205361
# Epoch: 1, Steps: 72 | Train Loss: 0.3711438 Vali Loss: 0.2034331 Test Loss: 0.2053606
# Validation loss decreased (inf --> 0.203433).  Saving model ...
# Updating learning rate to 4.276618710035313e-05
# Epoch: 3 cost time: 110.30789494514465
# Epoch: 1 cost time: 51.03451347351074
# Validation KL div loss: 0.104925
# Validation KL div loss: 0.150816
# Validation KL div loss: 0.150209
# Epoch: 1, Steps: 66 | Train Loss: 0.3166550 Vali Loss: 0.1508161 Test Loss: 0.1502092
# Validation loss decreased (inf --> 0.150816).  Saving model ...
# Updating learning rate to 7.49746040360264e-05
# Validation KL div loss: 0.105018
# Epoch: 3, Steps: 57 | Train Loss: 0.1260045 Vali Loss: 0.1049249 Test Loss: 0.1050177
# Validation loss decreased (0.111267 --> 0.104925).  Saving model ...
# Updating learning rate to 7.963862128750447e-05
# Epoch: 2 cost time: 40.72732663154602
# Validation KL div loss: 0.127425
# Validation KL div loss: 0.125905
# Epoch: 2, Steps: 72 | Train Loss: 0.1751498 Vali Loss: 0.1274254 Test Loss: 0.1259053
# Validation loss decreased (0.203433 --> 0.127425).  Saving model ...
# Updating learning rate to 2.1383093550176566e-05
# Epoch: 2 cost time: 44.03327655792236
# Validation KL div loss: 0.103004
# Validation KL div loss: 0.106663
# Epoch: 2, Steps: 66 | Train Loss: 0.1071551 Vali Loss: 0.1030043 Test Loss: 0.1066626
# Validation loss decreased (0.150816 --> 0.103004).  Saving model ...
# Updating learning rate to 3.74873020180132e-05
# Epoch: 5 cost time: 65.29822945594788
# Validation KL div loss: 0.107325
# Validation KL div loss: 0.107947
# Epoch: 5, Steps: 49 | Train Loss: 0.0995855 Vali Loss: 0.1073255 Test Loss: 0.1079473
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.7155232405586408e-05
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 4567
# test shape: (4567, 1, 16) (4567, 1, 16)
# test shape: (4567, 1, 16) (4567, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial3_val2/H1_BOCsubset_trial3_val2_hyperparameters.json
# [INFO] Validation Score: 0.09826026282140186
# [INFO] Training finished with metrics: {'val_score': 0.09826026282140186}
# Namespace(cell='H1', train_chroms=[2, 15, 17, 22], val_chroms=[10], test_chroms=[10], setting='H1_BOCsubset_trial3_val10', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=3, d_model=1024, n_heads=2, d_ff=512, dropout=0.11276811281350484, learning_rate=0.0002744837184893825, weight_decay=1.474037573163214e-06, factor=7, seq_len=64, batch_size=128, label_len=32, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 8332
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 2551
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# Epoch: 4 cost time: 91.78103256225586
# test 2551
# Epoch: 3 cost time: 62.02110576629639
# Validation KL div loss: 0.091627
# Validation KL div loss: 0.115422
# Validation KL div loss: 0.115314
# Epoch: 3, Steps: 72 | Train Loss: 0.1444572 Vali Loss: 0.1154222 Test Loss: 0.1153144
# Validation loss decreased (0.127425 --> 0.115422).  Saving model ...
# Updating learning rate to 1.0691546775088283e-05
# Validation KL div loss: 0.091168
# Epoch: 4, Steps: 57 | Train Loss: 0.1116002 Vali Loss: 0.0916266 Test Loss: 0.0911679
# Validation loss decreased (0.104925 --> 0.091627).  Saving model ...
# Updating learning rate to 3.981931064375224e-05
# Epoch: 3 cost time: 69.61972212791443
# Validation KL div loss: 0.098300
# Validation KL div loss: 0.097924
# Epoch: 3, Steps: 66 | Train Loss: 0.0843351 Vali Loss: 0.0983002 Test Loss: 0.0979236
# Validation loss decreased (0.103004 --> 0.098300).  Saving model ...
# Updating learning rate to 1.87436510090066e-05
# Epoch: 4 cost time: 38.523996114730835
# Validation KL div loss: 0.109239
# Validation KL div loss: 0.109733
# Epoch: 4, Steps: 72 | Train Loss: 0.1318382 Vali Loss: 0.1092395 Test Loss: 0.1097326
# Validation loss decreased (0.115422 --> 0.109239).  Saving model ...
# Updating learning rate to 5.3457733875441414e-06
# Epoch: 4 cost time: 41.48638153076172
# Validation KL div loss: 0.090087
# Validation KL div loss: 0.090420
# Epoch: 4, Steps: 66 | Train Loss: 0.0754763 Vali Loss: 0.0900871 Test Loss: 0.0904200
# Validation loss decreased (0.098300 --> 0.090087).  Saving model ...
# Updating learning rate to 9.3718255045033e-06
# Epoch: 1 cost time: 82.48834109306335
# Validation KL div loss: 0.176916
# Validation KL div loss: 0.175616
# Epoch: 1, Steps: 65 | Train Loss: 0.4246903 Vali Loss: 0.1769164 Test Loss: 0.1756156
# Validation loss decreased (inf --> 0.176916).  Saving model ...
# Updating learning rate to 0.0002744837184893825
# Epoch: 5 cost time: 44.04346299171448
# Validation KL div loss: 0.108024
# Validation KL div loss: 0.107620
# Epoch: 5, Steps: 72 | Train Loss: 0.1291276 Vali Loss: 0.1080245 Test Loss: 0.1076203
# Validation loss decreased (0.109239 --> 0.108024).  Saving model ...
# Updating learning rate to 2.6728866937720707e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 3310
# test shape: (3310, 1, 16) (3310, 1, 16)
# test shape: (3310, 1, 16) (3310, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial2_val6/H1_BOCsubset_trial2_val6_hyperparameters.json
# [INFO] Validation Score: 0.10802447766065598
# [INFO] Training finished with metrics: {'val_score': 0.10802447766065598}
# Namespace(cell='H1', train_chroms=[1, 6, 18, 21], val_chroms=[11], test_chroms=[11], setting='H1_BOCsubset_trial2_val11', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=1, d_layers=2, d_model=512, n_heads=2, d_ff=2048, dropout=0.2650615512984011, learning_rate=4.276618710035313e-05, weight_decay=0.0001809330882459594, factor=7, seq_len=32, batch_size=128, label_len=16, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# Epoch: 5 cost time: 100.73505473136902
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 9984
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 2575
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 2575
# Validation KL div loss: 0.083660
# Validation KL div loss: 0.083767
# Epoch: 5, Steps: 57 | Train Loss: 0.1078848 Vali Loss: 0.0836600 Test Loss: 0.0837670
# Validation loss decreased (0.091627 --> 0.083660).  Saving model ...
# Updating learning rate to 1.990965532187612e-05
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 4567
# test shape: (4567, 1, 16) (4567, 1, 16)
# test shape: (4567, 1, 16) (4567, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial1_val2/H1_BOCsubset_trial1_val2_hyperparameters.json
# [INFO] Validation Score: 0.08365997821092605
# [INFO] Training finished with metrics: {'val_score': 0.08365997821092605}
# Namespace(cell='H1', train_chroms=[2, 11, 18, 21], val_chroms=[10], test_chroms=[10], setting='H1_BOCsubset_trial1_val10', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=2, d_layers=3, d_model=256, n_heads=8, d_ff=1024, dropout=0.2517254868415988, learning_rate=0.0003185544851500179, weight_decay=0.0010460683090809655, factor=5, seq_len=64, batch_size=128, label_len=32, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 9339
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 2551
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# Epoch: 5 cost time: 68.8703453540802
# test 2551
# Validation KL div loss: 0.090555
# Validation KL div loss: 0.090128
# Epoch: 5, Steps: 66 | Train Loss: 0.0706018 Vali Loss: 0.0905548 Test Loss: 0.0901276
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 4.68591275225165e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 2172
# test shape: (2172, 1, 16) (2172, 1, 16)
# test shape: (2172, 1, 16) (2172, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial0_val9/H1_BOCsubset_trial0_val9_hyperparameters.json
# [INFO] Validation Score: 0.09008705103769898
# [INFO] Training finished with metrics: {'val_score': 0.09008705103769898}
# Namespace(cell='H1', train_chroms=[4, 9, 18, 22], val_chroms=[11], test_chroms=[11], setting='H1_BOCsubset_trial0_val11', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=3, d_model=1024, n_heads=8, d_ff=1024, dropout=0.06265400903132286, learning_rate=7.49746040360264e-05, weight_decay=0.009391295083058939, factor=3, seq_len=32, batch_size=128, label_len=16, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# Epoch: 1 cost time: 51.37198257446289
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 8048
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 2575
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 2575
# Epoch: 2 cost time: 85.44007897377014
# Validation KL div loss: 0.116743
# Validation KL div loss: 0.116321
# Epoch: 2, Steps: 65 | Train Loss: 0.1332412 Vali Loss: 0.1167428 Test Loss: 0.1163214
# Validation loss decreased (0.176916 --> 0.116743).  Saving model ...
# Updating learning rate to 0.00013724185924469126
# Epoch: 1 cost time: 31.44224452972412
# Validation KL div loss: 0.119781
# Validation KL div loss: 0.122878
# Epoch: 1, Steps: 62 | Train Loss: 0.2949029 Vali Loss: 0.1197811 Test Loss: 0.1228779
# Validation loss decreased (inf --> 0.119781).  Saving model ...
# Updating learning rate to 7.49746040360264e-05
# Epoch: 2 cost time: 26.062350034713745
# Validation KL div loss: 0.098976
# Validation KL div loss: 0.100490
# Epoch: 2, Steps: 62 | Train Loss: 0.1151587 Vali Loss: 0.0989757 Test Loss: 0.1004896
# Validation loss decreased (0.119781 --> 0.098976).  Saving model ...
# Updating learning rate to 3.74873020180132e-05
# Epoch: 3 cost time: 61.78070831298828
# Validation KL div loss: 0.094216
# Validation KL div loss: 0.094580
# Epoch: 3, Steps: 65 | Train Loss: 0.0950775 Vali Loss: 0.0942161 Test Loss: 0.0945803
# Validation loss decreased (0.116743 --> 0.094216).  Saving model ...
# Updating learning rate to 6.862092962234563e-05
# Epoch: 3 cost time: 31.68483805656433
# Validation KL div loss: 0.079640
# Validation KL div loss: 0.081090
# Epoch: 3, Steps: 62 | Train Loss: 0.0903584 Vali Loss: 0.0796401 Test Loss: 0.0810905
# Validation loss decreased (0.098976 --> 0.079640).  Saving model ...
# Updating learning rate to 1.87436510090066e-05
# Epoch: 4 cost time: 26.029608488082886
# Validation KL div loss: 0.076807
# Validation KL div loss: 0.079561
# Epoch: 4, Steps: 62 | Train Loss: 0.0784896 Vali Loss: 0.0768070 Test Loss: 0.0795613
# Validation loss decreased (0.079640 --> 0.076807).  Saving model ...
# Updating learning rate to 9.3718255045033e-06
# Epoch: 4 cost time: 63.42458391189575
# Validation KL div loss: 0.080385
# Validation KL div loss: 0.080488
# Epoch: 4, Steps: 65 | Train Loss: 0.0813461 Vali Loss: 0.0803854 Test Loss: 0.0804881
# Validation loss decreased (0.094216 --> 0.080385).  Saving model ...
# Epoch: 1 cost time: 179.40343952178955
# Updating learning rate to 3.4310464811172816e-05
# Validation KL div loss: 0.118788
# Validation KL div loss: 0.122176
# Epoch: 1, Steps: 72 | Train Loss: 0.3394582 Vali Loss: 0.1187884 Test Loss: 0.1221760
# Validation loss decreased (inf --> 0.118788).  Saving model ...
# Updating learning rate to 0.0003185544851500179
# Epoch: 5 cost time: 33.16959738731384
# Validation KL div loss: 0.073836
# Validation KL div loss: 0.075945
# Epoch: 5, Steps: 62 | Train Loss: 0.0743370 Vali Loss: 0.0738363 Test Loss: 0.0759453
# Validation loss decreased (0.076807 --> 0.073836).  Saving model ...
# Updating learning rate to 4.68591275225165e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 2575
# test shape: (2575, 1, 16) (2575, 1, 16)
# test shape: (2575, 1, 16) (2575, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial0_val11/H1_BOCsubset_trial0_val11_hyperparameters.json
# [INFO] Validation Score: 0.07383629363030195
# [INFO] Training finished with metrics: {'val_score': 0.07383629363030195}
# Namespace(cell='H1', train_chroms=[4, 9, 11, 22], val_chroms=[18], test_chroms=[18], setting='H1_BOCsubset_trial0_val18', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=3, d_model=1024, n_heads=8, d_ff=1024, dropout=0.06265400903132286, learning_rate=7.49746040360264e-05, weight_decay=0.009391295083058939, factor=3, seq_len=32, batch_size=128, label_len=16, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 9177
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 1446
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 1446
# Epoch: 1 cost time: 30.532013654708862
# Validation KL div loss: 0.102623
# Validation KL div loss: 0.104650
# Epoch: 1, Steps: 71 | Train Loss: 0.2888265 Vali Loss: 0.1026232 Test Loss: 0.1046502
# Validation loss decreased (inf --> 0.102623).  Saving model ...
# Updating learning rate to 7.49746040360264e-05
# Epoch: 5 cost time: 65.5727653503418
# Validation KL div loss: 0.082425
# Validation KL div loss: 0.083944
# Epoch: 5, Steps: 65 | Train Loss: 0.0744209 Vali Loss: 0.0824254 Test Loss: 0.0839442
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.7155232405586408e-05
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 2551
# test shape: (2551, 1, 16) (2551, 1, 16)
# test shape: (2551, 1, 16) (2551, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial3_val10/H1_BOCsubset_trial3_val10_hyperparameters.json
# [INFO] Validation Score: 0.08038543164730072
# [INFO] Training finished with metrics: {'val_score': 0.08038543164730072}
# Namespace(cell='H1', train_chroms=[2, 10, 17, 22], val_chroms=[15], test_chroms=[15], setting='H1_BOCsubset_trial3_val15', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=3, d_model=1024, n_heads=2, d_ff=512, dropout=0.11276811281350484, learning_rate=0.0002744837184893825, weight_decay=1.474037573163214e-06, factor=7, seq_len=64, batch_size=128, label_len=32, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 9416
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 1467
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 1467
# Epoch: 2 cost time: 43.41694617271423
# Validation KL div loss: 0.085856
# Validation KL div loss: 0.082842
# Epoch: 2, Steps: 71 | Train Loss: 0.1062597 Vali Loss: 0.0858561 Test Loss: 0.0828420
# Validation loss decreased (0.102623 --> 0.085856).  Saving model ...
# Updating learning rate to 3.74873020180132e-05
# Epoch: 3 cost time: 29.815553188323975
# Validation KL div loss: 0.079703
# Validation KL div loss: 0.075031
# Epoch: 3, Steps: 71 | Train Loss: 0.0819311 Vali Loss: 0.0797026 Test Loss: 0.0750310
# Validation loss decreased (0.085856 --> 0.079703).  Saving model ...
# Updating learning rate to 1.87436510090066e-05
# Epoch: 2 cost time: 138.80588507652283
# Validation KL div loss: 0.096593
# Validation KL div loss: 0.097185
# Epoch: 2, Steps: 72 | Train Loss: 0.1382559 Vali Loss: 0.0965932 Test Loss: 0.0971854
# Validation loss decreased (0.118788 --> 0.096593).  Saving model ...
# Updating learning rate to 0.00015927724257500895
# Epoch: 1 cost time: 71.32614064216614
# Validation KL div loss: 0.146690
# Validation KL div loss: 0.148968
# Epoch: 1, Steps: 73 | Train Loss: 0.3809982 Vali Loss: 0.1466898 Test Loss: 0.1489685
# Validation loss decreased (inf --> 0.146690).  Saving model ...
# Updating learning rate to 0.0002744837184893825
# Epoch: 4 cost time: 34.74828910827637
# Validation KL div loss: 0.077888
# Validation KL div loss: 0.072603
# Epoch: 4, Steps: 71 | Train Loss: 0.0738877 Vali Loss: 0.0778877 Test Loss: 0.0726033
# Validation loss decreased (0.079703 --> 0.077888).  Saving model ...
# Updating learning rate to 9.3718255045033e-06
# Epoch: 5 cost time: 29.91192650794983
# Validation KL div loss: 0.075832
# Validation KL div loss: 0.072743
# Epoch: 5, Steps: 71 | Train Loss: 0.0697700 Vali Loss: 0.0758321 Test Loss: 0.0727431
# Validation loss decreased (0.077888 --> 0.075832).  Saving model ...
# Updating learning rate to 4.68591275225165e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 1446
# test shape: (1446, 1, 16) (1446, 1, 16)
# test shape: (1446, 1, 16) (1446, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial0_val18/H1_BOCsubset_trial0_val18_hyperparameters.json
# [INFO] Validation Score: 0.07583213563669812
# [INFO] Training finished with metrics: {'val_score': 0.07583213563669812}
# Namespace(cell='H1', train_chroms=[4, 9, 11, 18], val_chroms=[22], test_chroms=[22], setting='H1_BOCsubset_trial0_val22', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=3, d_model=1024, n_heads=8, d_ff=1024, dropout=0.06265400903132286, learning_rate=7.49746040360264e-05, weight_decay=0.009391295083058939, factor=3, seq_len=32, batch_size=128, label_len=16, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 9973
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 650
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 650
# Epoch: 2 cost time: 68.68257355690002
# Validation KL div loss: 0.116786
# Validation KL div loss: 0.118906
# Epoch: 2, Steps: 73 | Train Loss: 0.1435547 Vali Loss: 0.1167857 Test Loss: 0.1189059
# Validation loss decreased (0.146690 --> 0.116786).  Saving model ...
# Updating learning rate to 0.00013724185924469126
# Epoch: 1 cost time: 35.47308015823364
# Validation KL div loss: 0.178042
# Validation KL div loss: 0.160515
# Epoch: 1, Steps: 77 | Train Loss: 0.2709149 Vali Loss: 0.1780419 Test Loss: 0.1605152
# Validation loss decreased (inf --> 0.178042).  Saving model ...
# Updating learning rate to 7.49746040360264e-05
# Epoch: 2 cost time: 32.25478482246399
# Validation KL div loss: 0.095451
# Validation KL div loss: 0.090747
# Epoch: 2, Steps: 77 | Train Loss: 0.0998576 Vali Loss: 0.0954510 Test Loss: 0.0907469
# Validation loss decreased (0.178042 --> 0.095451).  Saving model ...
# Updating learning rate to 3.74873020180132e-05
# Epoch: 3 cost time: 66.7246687412262
# Validation KL div loss: 0.088266
# Validation KL div loss: 0.090550
# Epoch: 3, Steps: 73 | Train Loss: 0.1028083 Vali Loss: 0.0882657 Test Loss: 0.0905503
# Validation loss decreased (0.116786 --> 0.088266).  Saving model ...
# Updating learning rate to 6.862092962234563e-05
# Epoch: 3 cost time: 175.51978135108948
# Validation KL div loss: 0.095394
# Validation KL div loss: 0.094919
# Epoch: 3, Steps: 72 | Train Loss: 0.1112514 Vali Loss: 0.0953944 Test Loss: 0.0949187
# Validation loss decreased (0.096593 --> 0.095394).  Saving model ...
# Updating learning rate to 7.963862128750447e-05
# Epoch: 3 cost time: 37.938995122909546
# Validation KL div loss: 0.090915
# Validation KL div loss: 0.083888
# Epoch: 3, Steps: 77 | Train Loss: 0.0776104 Vali Loss: 0.0909152 Test Loss: 0.0838879
# Validation loss decreased (0.095451 --> 0.090915).  Saving model ...
# Updating learning rate to 1.87436510090066e-05
# Epoch: 4 cost time: 32.18230485916138
# Validation KL div loss: 0.086755
# Validation KL div loss: 0.080129
# Epoch: 4, Steps: 77 | Train Loss: 0.0713198 Vali Loss: 0.0867551 Test Loss: 0.0801290
# Validation loss decreased (0.090915 --> 0.086755).  Saving model ...
# Updating learning rate to 9.3718255045033e-06
# Epoch: 4 cost time: 70.96647262573242
# Validation KL div loss: 0.081458
# Validation KL div loss: 0.082278
# Epoch: 4, Steps: 73 | Train Loss: 0.0854630 Vali Loss: 0.0814581 Test Loss: 0.0822782
# Validation loss decreased (0.088266 --> 0.081458).  Saving model ...
# Updating learning rate to 3.4310464811172816e-05
# Epoch: 5 cost time: 35.839311361312866
# Validation KL div loss: 0.084813
# Validation KL div loss: 0.079773
# Epoch: 5, Steps: 77 | Train Loss: 0.0672842 Vali Loss: 0.0848135 Test Loss: 0.0797733
# Validation loss decreased (0.086755 --> 0.084813).  Saving model ...
# Updating learning rate to 4.68591275225165e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 650
# test shape: (650, 1, 16) (650, 1, 16)
# test shape: (650, 1, 16) (650, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial0_val22/H1_BOCsubset_trial0_val22_hyperparameters.json
# [INFO] Validation Score: 0.08481348156929017
# [INFO] Training finished with metrics: {'val_score': 0.08481348156929017}
# [I 2025-11-25 23:44:39,265] Trial 0 finished with value: 0.07978628048818413 and parameters: {'e_layers': 3, 'd_layers': 3, 'd_model': 1024, 'n_heads': 8, 'd_ff': 1024, 'dropout': 0.06265400903132286, 'learning_rate': 7.49746040360264e-05, 'weight_decay': 0.009391295083058939, 'factor': 3, 'seq_len': 32}. Best is trial 0 with value: 0.07978628048818413.
# Namespace(cell='H1', train_chroms=[8, 11, 19, 22], val_chroms=[2], test_chroms=[2], setting='H1_BOCsubset_trial4_val2', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=1, d_model=512, n_heads=4, d_ff=2048, dropout=0.1328791816620708, learning_rate=1.2001257105897427e-05, weight_decay=0.001027952607514595, factor=5, seq_len=128, batch_size=128, label_len=64, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 7046
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 4503
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 4503
# Epoch: 1 cost time: 18.298611164093018
# Validation KL div loss: 0.585354
# Validation KL div loss: 0.581459
# Epoch: 1, Steps: 55 | Train Loss: 0.5880064 Vali Loss: 0.5853539 Test Loss: 0.5814591
# Validation loss decreased (inf --> 0.585354).  Saving model ...
# Updating learning rate to 1.2001257105897427e-05
# Epoch: 2 cost time: 18.498705625534058
# Validation KL div loss: 0.568183
# Validation KL div loss: 0.553574
# Epoch: 2, Steps: 55 | Train Loss: 0.5199805 Vali Loss: 0.5681830 Test Loss: 0.5535742
# Validation loss decreased (0.585354 --> 0.568183).  Saving model ...
# Updating learning rate to 6.000628552948713e-06
# Epoch: 3 cost time: 18.147376537322998
# Validation KL div loss: 0.407417
# Validation KL div loss: 0.405581
# Epoch: 3, Steps: 55 | Train Loss: 0.4549039 Vali Loss: 0.4074168 Test Loss: 0.4055813
# Validation loss decreased (0.568183 --> 0.407417).  Saving model ...
# Updating learning rate to 3.0003142764743567e-06
# Epoch: 5 cost time: 105.31619882583618
# Validation KL div loss: 0.078420
# Validation KL div loss: 0.079897
# Epoch: 5, Steps: 73 | Train Loss: 0.0796959 Vali Loss: 0.0784196 Test Loss: 0.0798967
# Validation loss decreased (0.081458 --> 0.078420).  Saving model ...
# Updating learning rate to 1.7155232405586408e-05
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 1467
# test shape: (1467, 1, 16) (1467, 1, 16)
# test shape: (1467, 1, 16) (1467, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial3_val15/H1_BOCsubset_trial3_val15_hyperparameters.json
# [INFO] Validation Score: 0.07841956547715447
# [INFO] Training finished with metrics: {'val_score': 0.07841956547715447}
# Namespace(cell='H1', train_chroms=[2, 10, 15, 22], val_chroms=[17], test_chroms=[17], setting='H1_BOCsubset_trial3_val17', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=3, d_layers=3, d_model=1024, n_heads=2, d_ff=512, dropout=0.11276811281350484, learning_rate=0.0002744837184893825, weight_decay=1.474037573163214e-06, factor=7, seq_len=64, batch_size=128, label_len=32, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 9395
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 1488
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 1488
# Epoch: 4 cost time: 26.05765461921692
# Validation KL div loss: 0.304478
# Validation KL div loss: 0.300892
# Epoch: 4, Steps: 55 | Train Loss: 0.3609325 Vali Loss: 0.3044776 Test Loss: 0.3008923
# Validation loss decreased (0.407417 --> 0.304478).  Saving model ...
# Updating learning rate to 1.5001571382371783e-06
# Epoch: 5 cost time: 18.140154123306274
# Validation KL div loss: 0.268213
# Validation KL div loss: 0.267021
# Epoch: 5, Steps: 55 | Train Loss: 0.3073370 Vali Loss: 0.2682127 Test Loss: 0.2670206
# Validation loss decreased (0.304478 --> 0.268213).  Saving model ...
# Updating learning rate to 7.500785691185892e-07
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 4503
# test shape: (4503, 1, 16) (4503, 1, 16)
# test shape: (4503, 1, 16) (4503, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial4_val2/H1_BOCsubset_trial4_val2_hyperparameters.json
# [INFO] Validation Score: 0.26821268200874326
# [INFO] Training finished with metrics: {'val_score': 0.26821268200874326}
# ...
# test 3652
# Epoch: 4 cost time: 64.68493413925171
# Validation KL div loss: 0.080978
# Validation KL div loss: 0.078519
# Epoch: 4, Steps: 88 | Train Loss: 0.0970782 Vali Loss: 0.0809780 Test Loss: 0.0785192
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.981931064375224e-05
# test shape: (3652, 1, 16) (3652, 1, 16)
# test shape: (3652, 1, 16) (3652, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial9_val4/H1_BOCsubset_trial9_val4_hyperparameters.json
# [INFO] Validation Score: 0.11036813205906323
# [INFO] Training finished with metrics: {'val_score': 0.11036813205906323}
# Namespace(cell='H1', train_chroms=[4, 13, 18, 21], val_chroms=[10], test_chroms=[10], setting='H1_BOCsubset_trial9_val10', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=1, d_layers=3, d_model=1024, n_heads=4, d_ff=1024, dropout=0.09836616288560356, learning_rate=2.6725624421611923e-05, weight_decay=0.0028029272559071407, factor=7, seq_len=64, batch_size=128, label_len=32, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 7738
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 2551
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 2551
# Epoch: 1 cost time: 19.691099643707275
# Validation KL div loss: 0.199333
# Validation KL div loss: 0.199079
# Epoch: 1, Steps: 60 | Train Loss: 0.3986004 Vali Loss: 0.1993334 Test Loss: 0.1990785
# Validation loss decreased (inf --> 0.199333).  Saving model ...
# Updating learning rate to 2.6725624421611923e-05
# Epoch: 2 cost time: 19.483614683151245
# Validation KL div loss: 0.142900
# Validation KL div loss: 0.143336
# Epoch: 2, Steps: 60 | Train Loss: 0.1437783 Vali Loss: 0.1428995 Test Loss: 0.1433364
# Validation loss decreased (0.199333 --> 0.142900).  Saving model ...
# Updating learning rate to 1.3362812210805961e-05
# Epoch: 5 cost time: 62.276737689971924
# Validation KL div loss: 0.073689
# Validation KL div loss: 0.072805
# Epoch: 5, Steps: 88 | Train Loss: 0.0932650 Vali Loss: 0.0736895 Test Loss: 0.0728048
# Validation loss decreased (0.074782 --> 0.073689).  Saving model ...
# Updating learning rate to 1.990965532187612e-05
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 623
# test shape: (623, 1, 16) (623, 1, 16)
# test shape: (623, 1, 16) (623, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial1_val21/H1_BOCsubset_trial1_val21_hyperparameters.json
# [INFO] Validation Score: 0.07368945516645908
# [INFO] Training finished with metrics: {'val_score': 0.07368945516645908}
# [I 2025-11-26 00:31:47,503] Trial 1 finished with value: 0.07897026146035731 and parameters: {'e_layers': 2, 'd_layers': 3, 'd_model': 256, 'n_heads': 8, 'd_ff': 1024, 'dropout': 0.2517254868415988, 'learning_rate': 0.0003185544851500179, 'weight_decay': 0.0010460683090809655, 'factor': 5, 'seq_len': 64}. Best is trial 1 with value: 0.07897026146035731.
# Epoch: 3 cost time: 19.811840772628784
# Validation KL div loss: 0.130788
# Validation KL div loss: 0.129819
# Epoch: 3, Steps: 60 | Train Loss: 0.1182220 Vali Loss: 0.1307879 Test Loss: 0.1298188
# Validation loss decreased (0.142900 --> 0.130788).  Saving model ...
# Updating learning rate to 6.681406105402981e-06
# Epoch: 4 cost time: 17.073758363723755
# Validation KL div loss: 0.127557
# Validation KL div loss: 0.125976
# Epoch: 4, Steps: 60 | Train Loss: 0.1078502 Vali Loss: 0.1275571 Test Loss: 0.1259756
# Validation loss decreased (0.130788 --> 0.127557).  Saving model ...
# Updating learning rate to 3.3407030527014903e-06
# Epoch: 5 cost time: 17.285093784332275
# Validation KL div loss: 0.123742
# Validation KL div loss: 0.123412
# Epoch: 5, Steps: 60 | Train Loss: 0.1040024 Vali Loss: 0.1237421 Test Loss: 0.1234121
# Validation loss decreased (0.127557 --> 0.123742).  Saving model ...
# Updating learning rate to 1.6703515263507452e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 2551
# test shape: (2551, 1, 16) (2551, 1, 16)
# test shape: (2551, 1, 16) (2551, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial9_val10/H1_BOCsubset_trial9_val10_hyperparameters.json
# [INFO] Validation Score: 0.1237421361239333
# [INFO] Training finished with metrics: {'val_score': 0.1237421361239333}
# Namespace(cell='H1', train_chroms=[4, 10, 18, 21], val_chroms=[13], test_chroms=[13], setting='H1_BOCsubset_trial9_val13', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=1, d_layers=3, d_model=1024, n_heads=4, d_ff=1024, dropout=0.09836616288560356, learning_rate=2.6725624421611923e-05, weight_decay=0.0028029272559071407, factor=7, seq_len=64, batch_size=128, label_len=32, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 8432
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 1857
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 1857
# Epoch: 1 cost time: 18.49447274208069
# Validation KL div loss: 0.158880
# Validation KL div loss: 0.163644
# Epoch: 1, Steps: 65 | Train Loss: 0.4030615 Vali Loss: 0.1588800 Test Loss: 0.1636436
# Validation loss decreased (inf --> 0.158880).  Saving model ...
# Updating learning rate to 2.6725624421611923e-05
# Epoch: 2 cost time: 18.44798731803894
# Validation KL div loss: 0.114939
# Validation KL div loss: 0.116542
# Epoch: 2, Steps: 65 | Train Loss: 0.1483502 Vali Loss: 0.1149393 Test Loss: 0.1165419
# Validation loss decreased (0.158880 --> 0.114939).  Saving model ...
# Updating learning rate to 1.3362812210805961e-05
# Epoch: 3 cost time: 18.425315618515015
# Validation KL div loss: 0.104893
# Validation KL div loss: 0.109255
# Epoch: 3, Steps: 65 | Train Loss: 0.1178787 Vali Loss: 0.1048931 Test Loss: 0.1092553
# Validation loss decreased (0.114939 --> 0.104893).  Saving model ...
# Updating learning rate to 6.681406105402981e-06
# Epoch: 4 cost time: 18.46047306060791
# Validation KL div loss: 0.099384
# Validation KL div loss: 0.103127
# Epoch: 4, Steps: 65 | Train Loss: 0.1093606 Vali Loss: 0.0993842 Test Loss: 0.1031266
# Validation loss decreased (0.104893 --> 0.099384).  Saving model ...
# Updating learning rate to 3.3407030527014903e-06
# Epoch: 5 cost time: 18.405967712402344
# Validation KL div loss: 0.098732
# Validation KL div loss: 0.099837
# Epoch: 5, Steps: 65 | Train Loss: 0.1034971 Vali Loss: 0.0987321 Test Loss: 0.0998372
# Validation loss decreased (0.099384 --> 0.098732).  Saving model ...
# Updating learning rate to 1.6703515263507452e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 1857
# test shape: (1857, 1, 16) (1857, 1, 16)
# test shape: (1857, 1, 16) (1857, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial9_val13/H1_BOCsubset_trial9_val13_hyperparameters.json
# [INFO] Validation Score: 0.098732093083007
# [INFO] Training finished with metrics: {'val_score': 0.098732093083007}
# Namespace(cell='H1', train_chroms=[4, 10, 13, 21], val_chroms=[18], test_chroms=[18], setting='H1_BOCsubset_trial9_val18', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=1, d_layers=3, d_model=1024, n_heads=4, d_ff=1024, dropout=0.09836616288560356, learning_rate=2.6725624421611923e-05, weight_decay=0.0028029272559071407, factor=7, seq_len=64, batch_size=128, label_len=32, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 8875
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 1414
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 1414
# Epoch: 1 cost time: 19.584163665771484
# Validation KL div loss: 0.149284
# Validation KL div loss: 0.145053
# Epoch: 1, Steps: 69 | Train Loss: 0.3738427 Vali Loss: 0.1492842 Test Loss: 0.1450534
# Validation loss decreased (inf --> 0.149284).  Saving model ...
# Updating learning rate to 2.6725624421611923e-05
# Epoch: 2 cost time: 19.598586797714233
# Validation KL div loss: 0.107661
# Validation KL div loss: 0.103007
# Epoch: 2, Steps: 69 | Train Loss: 0.1411730 Vali Loss: 0.1076614 Test Loss: 0.1030066
# Validation loss decreased (0.149284 --> 0.107661).  Saving model ...
# Updating learning rate to 1.3362812210805961e-05
# Epoch: 3 cost time: 19.842541217803955
# Validation KL div loss: 0.094986
# Validation KL div loss: 0.090536
# Epoch: 3, Steps: 69 | Train Loss: 0.1162208 Vali Loss: 0.0949863 Test Loss: 0.0905364
# Validation loss decreased (0.107661 --> 0.094986).  Saving model ...
# Updating learning rate to 6.681406105402981e-06
# Epoch: 4 cost time: 19.53273606300354
# Validation KL div loss: 0.089108
# Validation KL div loss: 0.085829
# Epoch: 4, Steps: 69 | Train Loss: 0.1063707 Vali Loss: 0.0891082 Test Loss: 0.0858285
# Validation loss decreased (0.094986 --> 0.089108).  Saving model ...
# Updating learning rate to 3.3407030527014903e-06
# Epoch: 5 cost time: 19.606525421142578
# Validation KL div loss: 0.088153
# Validation KL div loss: 0.084271
# Epoch: 5, Steps: 69 | Train Loss: 0.1023823 Vali Loss: 0.0881530 Test Loss: 0.0842705
# Validation loss decreased (0.089108 --> 0.088153).  Saving model ...
# Updating learning rate to 1.6703515263507452e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 1414
# test shape: (1414, 1, 16) (1414, 1, 16)
# test shape: (1414, 1, 16) (1414, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial9_val18/H1_BOCsubset_trial9_val18_hyperparameters.json
# [INFO] Validation Score: 0.0881530452858318
# [INFO] Training finished with metrics: {'val_score': 0.0881530452858318}
# Namespace(cell='H1', train_chroms=[4, 10, 13, 18], val_chroms=[21], test_chroms=[21], setting='H1_BOCsubset_trial9_val21', checkpoints='/content/CS401-soffritto/transofritto/checkpoints', e_layers=1, d_layers=3, d_model=1024, n_heads=4, d_ff=1024, dropout=0.09836616288560356, learning_rate=2.6725624421611923e-05, weight_decay=0.0028029272559071407, factor=7, seq_len=64, batch_size=128, label_len=32, pred_len=1, enc_in=9, dec_in=16, c_out=16, activation='gelu', attn='prob', train_epochs=5, patience=3, lradj='type1', num_workers=4, use_multi_gpu=False, gpu=0, devices='0', selected_cols=['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage'], root_path='/content/CS401-soffritto/transofritto/data', data_path='/content/CS401-soffritto/transofritto/data/H1_genomic.csv', results_path='/content/CS401-soffritto/transofritto/results', model='informer', target='target_1', freq='w', embed='timeF', output_attention=False, distil=False, mix=False, data='custom', features='M', inverse=False, padding=0)
# Use GPU: cuda:0
# [WAVELET/MODEL] OFF
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# train 9666
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# val 623
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 623
# Epoch: 1 cost time: 21.342637538909912
# Validation KL div loss: 0.131960
# Validation KL div loss: 0.133736
# Epoch: 1, Steps: 75 | Train Loss: 0.3617881 Vali Loss: 0.1319603 Test Loss: 0.1337365
# Validation loss decreased (inf --> 0.131960).  Saving model ...
# Updating learning rate to 2.6725624421611923e-05
# Epoch: 2 cost time: 21.51808762550354
# Validation KL div loss: 0.107518
# Validation KL div loss: 0.104017
# Epoch: 2, Steps: 75 | Train Loss: 0.1320403 Vali Loss: 0.1075181 Test Loss: 0.1040172
# Validation loss decreased (0.131960 --> 0.107518).  Saving model ...
# Updating learning rate to 1.3362812210805961e-05
# Epoch: 3 cost time: 21.53012251853943
# Validation KL div loss: 0.097281
# Validation KL div loss: 0.094379
# Epoch: 3, Steps: 75 | Train Loss: 0.1071380 Vali Loss: 0.0972809 Test Loss: 0.0943795
# Validation loss decreased (0.107518 --> 0.097281).  Saving model ...
# Updating learning rate to 6.681406105402981e-06
# Epoch: 4 cost time: 21.5155131816864
# Validation KL div loss: 0.088338
# Validation KL div loss: 0.087893
# Epoch: 4, Steps: 75 | Train Loss: 0.0972988 Vali Loss: 0.0883379 Test Loss: 0.0878930
# Validation loss decreased (0.097281 --> 0.088338).  Saving model ...
# Updating learning rate to 3.3407030527014903e-06
# Epoch: 5 cost time: 21.64043664932251
# Validation KL div loss: 0.087865
# Validation KL div loss: 0.089411
# Epoch: 5, Steps: 75 | Train Loss: 0.0940043 Vali Loss: 0.0878650 Test Loss: 0.0894107
# Validation loss decreased (0.088338 --> 0.087865).  Saving model ...
# Updating learning rate to 1.6703515263507452e-06
# ['H3K27ac', 'H3K27me3', 'H3K36me3', 'H3K4me1', 'H3K4me3', 'H3K9me3', 'GC_content', 'gene_density', '2-stage']
# test 623
# test shape: (623, 1, 16) (623, 1, 16)
# test shape: (623, 1, 16) (623, 1, 16)
# [INFO] Hyperparameters saved to /content/CS401-soffritto/transofritto/checkpoints/H1_BOCsubset_trial9_val21/H1_BOCsubset_trial9_val21_hyperparameters.json
# [INFO] Validation Score: 0.08786497078835964
# [INFO] Training finished with metrics: {'val_score': 0.08786497078835964}
# [I 2025-11-26 00:38:39,924] Trial 9 finished with value: 0.10177207546803899 and parameters: {'e_layers': 1, 'd_layers': 3, 'd_model': 1024, 'n_heads': 4, 'd_ff': 1024, 'dropout': 0.09836616288560356, 'learning_rate': 2.6725624421611923e-05, 'weight_decay': 0.0028029272559071407, 'factor': 7, 'seq_len': 64}. Best is trial 1 with value: 0.07897026146035731.
