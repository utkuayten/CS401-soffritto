# %% [markdown]
# <a href="https://colab.research.google.com/github/utkuayten/CS401-soffritto/blob/main/optuna_informer_BOCO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install optuna
# !git clone https://github.com/utkuayten/CS401-soffritto
# Out:
# ...
# Cloning into 'CS401-soffritto'...
# remote: Enumerating objects: 1658, done.
# remote: Counting objects: 100% (134/134), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 1658 (delta 81), reused 84 (delta 42), pack-reused 1524 (from 2)
# Receiving objects: 100% (1658/1658), 764.76 MiB | 16.68 MiB/s, done.
# Resolving deltas: 100% (904/904), done.
# Updating files: 100% (435/435), done.

# %%
# !python3 CS401-soffritto/transofritto/optuna_BOCO.py --cell H1 --n_trials 10 --group_size 25
# Out:
# [I 2025-11-27 13:13:37,882] A new study created in memory with name: no-name-901bd530-5331-4c39-a985-fb5a37749ae1
# ...
